# %%
import pandas as pd
import re

# Read your CSV file and the Excel file
df_services = pd.read_csv('D:\\DataFrame\\Services.csv', header=0, encoding='ISO-8859-1')
df_medicine = pd.read_csv('D:\\DataFrame\\Medicine.csv', usecols=['ItemName'], encoding='ISO-8859-1')
df_plan_of_care = pd.read_excel("Downloads//EMR.xlsx")

# Filter the DataFrame to keep only rows where the 'Template' column is 'Plan of care'
df_filtered = df_plan_of_care[df_plan_of_care['Template'] == 'Plan of care']

# Split the ServiceName into two columns based on the first occurrence of '('
df_services[['ServiceName_Part1', 'ServiceName_Part2']] = df_services['ServiceName'].str.split('(', n=1, expand=True)

# Clean the second part of the ServiceName
df_services['ServiceName_Part2'] = df_services['ServiceName_Part2'].str.strip().str.rstrip(')').str.lstrip('(')
df_services = df_services[['ServiceName_Part1', 'ServiceName_Part2']]

# Create a new column with the first string from ItemName
df_medicine['FirstString'] = df_medicine['ItemName'].apply(lambda x: x.split()[0])

# List of tests and medicine keywords (replace the ellipsis with actual lists)
tests = [
    "PT INR", "COMPLETE HGM", "ESR", "PERIPHERAL BLOOD FILM", "HBA1C", "APTT", "TSH", 
    "RA FACTOR", "ECG", "BLOOD C/S", "NT PROBNP", "PROCALCITONIN", "URINE R/M C/S", 
    "LFT", "KFT", "MRI BRAIN WITH MRA BRAIN NECK", "Calcium", "Urine R/M", "ECHO", 
    "CPK", "CKMB", "TROP I", "Chest X-ray PA", "B12", "USG Whole Abdomen", 
    "ANA - IF", "Lipid Profile", "Anti TPO", "USG Neck", "Thyroid Profile", "MRI Brain", 
    "Whole Spine Screening", "CT Chest", "ANA Immunoblot 17 Antigen", "DEXA Scan Whole Body", 
    "Sudoscan", "BMI", "Renal Artery Doppler", "Holter", "FBS", "PPBS", 
    "Sugar Charting with Glucometer", "Fundus and Refraction", "CBC", "RFT", "INR", 
    "AFP", "PSA", "Urine Routine and Culture", "USG Abdomen with PVR", "Uroflowmetry", 
    "Ultrasound Thyroid Gland", "HbsAg", "Anti HCV", "NT Pro BNP", "Peripheral Smear for Blood Picture", 
    "Dietician Opinion for Diabetic Diet", "UGIE/RUT", "Fibroscan-Liver", 
    "CECT Abdomen (Negative Oral Contrast)", "CECT Abdomen (IV and Oral Contrast)", "PS MP", 
    "Malarial Antigen", "Dengue NS1 Antigen", "Dengue Serology IgG IgM", "Scrub Typhus IgM", 
    "Typhi Dot IgM", "Chikungunya Serology IgG IgM", "Leptospira Serology IgG IgM", "Blood Sugar R", 
    "ABPM", "USG W/A", "SR PSA Free Total", "Chest X-Ray PA", "Sputum AFB Gram Stain C/S KOH", 
    "GeneXpert", "MRI Angio Brain and Neck", "Ultrasound Abdomen", "FibroScan", "PT INR APTT", 
    "Blood C/S"
]

medicine_keywords = [
    'CAPSULES', 'CREAM & OINTMENT', 'DROPS', 'GARGLE', 'INHALER',
    'INJECTION', 'LOTIONS', 'MISCELLANEOUS', 'PATCH', 'POWDER',
    'RESPULES', 'ROTACAP', 'SACHET', 'SPRAYS', 'SUPPOSITORY', 'SYRUP',
    'TABLET', 'VACCINE', 'CREAM', 'EYE OINTMENT', 'GEL',
    'SKIN OINTMENT', 'EAR DROP', 'EYE & EAR DROP', 'EYE DROP',
    'NASAL DROP', 'ORAL DROP', 'NASAL SPRAY', 'SKIN SPRAY', 'SPACER', 'TAB',
    'CustomMedication', 'SOLUTION', 'TOOTH PASTE', 'TAB.', 'tab', 'Tab.', 
    'Tab', 'SYP', 'syp', 'syp.', 'Syp', 'Syp.', 'INJ', 'INJ.', 'inj', 
    'Inj.', 'Inj', 'CAP', 'CAP.', 'cap.', 'cap', 'Cap', 'Cap.', 'NS', 'NS.'
]

# Iterate over each row in the filtered DataFrame
for _, row in df_filtered.iterrows():
    visit_id = row['VisitId']
    data = row['Data']
    
    # Split the 'Data' column into sentences based on '<br/>' or ',' as delimiters
    sentences = [sentence.strip() for sentence in data.replace('<br/>', ',').split(',')]
    
    matching_tests = set()
    matching_medicine = set()
    
    for sentence in sentences:
        lower_sentence = sentence.lower()
        lower_service_part1 = df_services['ServiceName_Part1'].str.lower()
        lower_service_part2 = df_services['ServiceName_Part2'].str.lower()
        
        if lower_sentence in lower_service_part1.values or lower_sentence in lower_service_part2.values:
            matching_tests.add(sentence.upper())  # Convert to uppercase before adding

        # Find matches in the test list
        matches = [test.lower() for test in tests if re.search(rf'\b{re.escape(test)}\b', sentence, re.IGNORECASE)]
        for match in matches:
            matching_tests.add(match.upper())  # Convert to uppercase before adding
            
        # Find matches in the medicine keywords
        for medicine in medicine_keywords:
            if re.search(rf'\b{re.escape(medicine.lower())}\b', lower_sentence):
                matching_medicine.add(sentence.upper())  # Add the original sentence in uppercase
    
    # Print the matching tests and medicines with their VisitId
    if matching_tests or matching_medicine:
        print(f"\nVisitId: {visit_id}")
        if matching_tests:
            print("Matching Tests : ==> ")
            for match in matching_tests:
                print(match)
        if matching_medicine:
            print("Matching Medicines : ==> ")
            for match in matching_medicine:
                print(match)
# Out:
# VisitId: 2379379
# Matching Tests : ==>
# CBC
# KFT
# LFT
# Matching Medicines : ==>
# TAB CALPOL 500 MG SOS FOR PAIN
#
# VisitId: 2379393
# Matching Medicines : ==>
# TAB. IVABRAD 5 MG 1 TAB TWICE DAILY (AT 7 AM AND 7 PM)
# TAB. PANTOCID 40 MG ORALLYONCE DAILY BEFORE BREAKFAST
# TAB. MUCINAC 600 MG 1 TAB TWICE DAILY DISSOLVE IN WATER
# TAB. PLANEP T 25/10 MG 1 TAB ONCE DAILY (AT 10 AM )
# TAB. DAPLO 10 MG 1 TAB ONCE DAILY WITH LUNCH
# TAB. BRILINTA 90 MG ORALLY TWICE DAILY (10:00 AM / 10:00 PM)
# TAB. ATORVA 80 MG ORALLYONCE DAILY AT BED TIME
# TAB. ECOSPRIN 75 MG ORALLYONCE DAILY AT BED TIME
# TAB. AZMARDA 100 MG 1 TAB TWICE DAILY (AT 7 AMD AND 7 PM)
#
# VisitId: 2379393
# Matching Medicines : ==>
# LOFTAIR INHALER INHALATION ONCE DAILY FOLLOWED BY GARGLES
#
# VisitId: 2379395
# Matching Tests : ==>
# ECHO
# FIBROSCAN
# ECG
# Matching Medicines : ==>
# TAB JARDIANCE MET 12.5/500 MG 1 BD
# TAB THYROX 37.5 MCG 1 OD
# TAB ROSEDAY 10 MG 1 OD
# TAB SHALCAL XT 1 OD
#
# VisitId: 2379412
# Matching Tests : ==>
# PSA
# FIBROSCAN
# Matching Medicines : ==>
# TAB BENITOWA 8 MG 1 OD
# TAB JARDIANCE 12.5/500 MG 1 OD
# TAB ROSEDAY 10 MG 1 OD
# TAB SHALCAL XT 1 OD
#
# VisitId: 2379416
# Matching Tests : ==>
# TSH
# CBC
# KFT
# LFT
# USG NECK
# THYROID PROFILE
# Matching Medicines : ==>
# TAB CALPOL 650 MG SOS FOR FEVER
#
# VisitId: 2379423
# Matching Tests : ==>
# HBA1C
# HBSAG
# RA FACTOR
# ANTI HCV
# ESR
# URINE R/M
# COMPLETE HGM
# ECG
# KFT
# FIBROSCAN
# LFT
# PERIPHERAL BLOOD FILM
# GENEXPERT
# BMI
# SPUTUM AFB GRAM STAIN C/S KOH
# Matching Medicines : ==>
# CAP D RISE ONCE WEEKLY FOR 2 WEEKS
# TAB DOXY 100 MG TWICE DAILY FOR 5 DAYS (AFTER MEALS)
# CAP. ABETANEURON D3 ONCE DAILY 15 DAYS
# TAB. VELOZ 40 MG 1 TAB ONCE DAILY FOR 5 DAYS (EMPTY STOMACH DAILY MORNING)
# TAB. ONDEM MD 4 MG 1 TAB SOS (FOR NAUSEA AND VOMITING)
# TAB. FARONEM ER 300 MG 1 TAB TWICE DAILY FOR 5 DAYS (AFTER MEALS)
# TAB OROFER XT 1 TAB ONCE DAILY FOR 1 MONTH
# CAP. VSL 3 ONCE DAILY FOR 5 DAYS
# TAB. CALPOL 650 MG 1 TAB SOS (FOR FEVER AND HEADACHE)
#
# VisitId: 2379424
# Matching Tests : ==>
# UROFLOWMETRY
#
# VisitId: 2379425
# Matching Tests : ==>
# UROFLOWMETRY
#
# VisitId: 2379430
# Matching Tests : ==>
# TSH
# ANTI TPO
# COMPLETE HGM
# ECG
# KFT
# FBS
# PERIPHERAL BLOOD FILM
# SUGAR CHARTING WITH GLUCOMETER
# PPBS
# THYROID PROFILE
# Matching Medicines : ==>
# TAB VOLIBO 0.3 MG THRICE DAILY BEFORE BREAKFAST LUNCH AND DINNER
# TAB ONDERO0MET 2.5/1000 MG TWICE DAILY AFTER BREAKFAST AND DINNER
# TAB AMARYL 2 MG ONCE DAILY MORNING BEFORE BREAKFAST AND 1 MG ONCE DAILY BEFORE DINNER
#
# VisitId: 2379435
# Matching Tests : ==>
# ECHO
# CBC
# CPK
# SUDOSCAN
# ECG
# TROP I
# KFT
# B12
# LFT
# FIBROSCAN
#
# VisitId: 2379438
# Matching Tests : ==>
# USG CHEST
#
# VisitId: 2379443
# Matching Tests : ==>
# SIGMOIDOSCOPY
#
# VisitId: 2379450
# Matching Medicines : ==>
# TAB MONTEC LC 1 OD
# TAB CALPOL 650 MG 1 SOS
# TAB TAXIM O 200 MG 1 BD
#
# VisitId: 2379476
# Matching Medicines : ==>
# TAB BREVIPIL 50 MG 1 TAB TWICE DAILY TO CONTINUE
# TAB THYROXINE 25 MCG 1 TAB BEFORE BREAKFAST
# TAB. D- VENIZEP LS 50/0.25 1 TAB ONCE DAILY AT BEDTIME
# TAB. REJUNEX CD3 1 TAB ONCE DAILY
#
# VisitId: 2379483
# Matching Tests : ==>
# TSH
# CBC
# LIPASE
# KFT
# B12
# LFT
#
# VisitId: 2379490
# Matching Medicines : ==>
# IVF NS @ 80 ML /HR
# INJ NEXFORT 2.5 GM IV TDS
# INJ EMESET 4 MG IV TDS
# SYP BROZEDEX 10 ML BD
# TAB CARDIVAS 6.25 ONCE DAILY
# INJ VITCOR  IV BD
# INJ PCM 1 GM IV TDS
# TAB STAMLO 5 MG BD
# INJ ESOTUM 40 MG IV BD
#
# VisitId: 2379500
# Matching Tests : ==>
# CBC
# TYPHI DOT IGM
# CRP
#
# VisitId: 2379504
# Matching Tests : ==>
# BLOOD C/S
# ESR
# CBC
# LFT
# CRP
#
# VisitId: 2379518
# Matching Medicines : ==>
# TAB OLEANZ 2.5 MG 1 TAB AFTER DINNER
# TAB PETRIL MD 0.25 MG SOS FOR ANXIETY
# TAB GEMCAL 1 TAB ONCE DAILY AFTER FOOD
# TAB GABATOR NT 100 MG 1 TAB AFTER DINNER
# TAB DEPRAN 10 MG1 TAB AFTER DINNER
#
# VisitId: 2379528
# Matching Medicines : ==>
# TAB GABAPIN NT 100 MG 1 TAB AFTER DINNER
# TAB ECOSPRIN AV 75/20 MG 1 TAB AFTER DINNER
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB LEVIPIL 500 MG 1 TAB TWICE DAILY AFTER FOOD
# CAP DUZELA 30 MG 1 CAP AFTER DINNER
# TAB LACOSAM 150 MG 1 TAB TWIEC DAILY AFTER FOOD
#
# VisitId: 2379537
# Matching Tests : ==>
# KFT
#
# VisitId: 2379538
# Matching Medicines : ==>
# IVF NS @ 80 ML /HR
# INJ EMESET 4 MG IV TDS
# INJ VITCOR  IV BD
# INJ DOXY 100 MG IV BD
# INJ PCM 1 GM IV TDS
# INJ NEXFORT - T 2.5 GM IV TDS
# INJ ESOTUM 40 MG IV BD
#
# VisitId: 2379549
# Matching Medicines : ==>
# TAB NEUROBION FORTE 1 TAB OD X 2 WEEKS
# MASSAGE WITH MOISTUREX CREAM THREE TIMES A DAY TILL RT STARTS
#
# VisitId: 2379557
# Matching Medicines : ==>
# TAB CONCOR 2.5 MG TWICE DAILY 7.00AM/7.00PM
# TAB URIMAX 0.2 MG BEDTIME
# TAB ATORVA 80 MG BEDTIME
# TAB PLANEP 25 MG 1 OD 10.00AM
# TAB DYTOR 10 MG 1 HS AT BEDTIME
# TAB ECOSPRIN 75 MG BEDTIME
# TAB ARNICOR 50 MG 1 BID 7.00AM/7.00PM
# TAB BRILINTA 90 MG TWICE DAILY 10.00AM/10.00PM
#
# VisitId: 2379569
# Matching Tests : ==>
# HBA1C
# ECHO
# USG WHOLE ABDOMEN
# CALCIUM
# URINE R/M
# ECG
# LIPID PROFILE
# APTT
# B12
# DEXA SCAN WHOLE BODY
# RA FACTOR
# PT INR
# KFT
# MRI BRAIN
# THYROID PROFILE
# ANTI HCV
# ESR
# FUNDUS AND REFRACTION
# CPK
# COMPLETE HGM
# TROP I
# LFT
# PERIPHERAL BLOOD FILM
# WHOLE SPINE SCREENING
# ANTI TPO
# CKMB
# PT INR APTT
# ANA - IF
# HBSAG
# INR
# USG NECK
# Matching Medicines : ==>
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
# CAP VELOZ 40 MG ONCE DAILY EMPTY STOMACH
# CAP NERVZ B ONCE DAILY - 15 DAYS
# CAP D RISE 60 K ONCE WEEKLY 4 WEEKS
#
# VisitId: 2379572
# Matching Tests : ==>
# TSH
# HBA1C
# ECHO
# URINE R/M
# ECG
# TYPHI DOT IGM
# KFT
# URINE R/M C/S
# PS MP
# BLOOD C/S
# ESR
# CPK
# COMPLETE HGM
# TROP I
# GENEXPERT
# LFT
# PERIPHERAL BLOOD FILM
# DENGUE SEROLOGY IGG IGM
# MALARIAL ANTIGEN
# SCRUB TYPHUS IGM
# Matching Medicines : ==>
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
# TAB AZEE 500 MG ONCE DAILY 5 DAYS
# DENGUE NS 1 ANTIGEN
# CAP NERVZ B ONCE DAILY 15 DAYS
# CAP VELOZ 40 MG ONCE DAILY EMPTY STOMACH - 5 DAYS
# CAP. VSL 3 ONCE DAILY 5 DAYS
# TAB ALLEGRA 180 MG ONCE DAILY NIGHT 5 DAYS
# TAB TAXIM O 400 MG TWICE DAILY 5 DAYS
# SYP PIRITON CS 1 TSP SOS FOR COUGH
#
# VisitId: 2379579
# Matching Tests : ==>
# ULTRASOUND NECK
# PT INR
# ECG
# HBSAG
# INR
#
# VisitId: 2379581
# Matching Tests : ==>
# ECHO
#
# VisitId: 2379585
# Matching Tests : ==>
# CALCIUM
#
# VisitId: 2379606
# Matching Medicines : ==>
# TAB BETHERAN 1 TAB BDS FOR 30 DAYS
#
# VisitId: 2379613
# Matching Tests : ==>
# TSH
# HBA1C
# URINE R/M
# ECG
# LIPID PROFILE
# APTT
# RA FACTOR
# PT INR
# PSA
# KFT
# ESR
# COMPLETE HGM
# FIBROSCAN
# LFT
# PERIPHERAL BLOOD FILM
# SR PSA FREE TOTAL
# PT INR APTT
# INR
# AMMONIA
# Matching Medicines : ==>
# TAB UDILIV 150 MG TWICE DAILY 10 DAYS
# CAP. VSL 3 ONCE DAILY FOR 7 DAYS
# TAB ABETANEURON D3 ONCE DAILY FOR 20 DAYS
# TAB ZINASE D TWICE DAILY 3 DAYS THEN SOS
# TAB. ONDEM MD 4 MG 1 TAB SOS (FOR NAUSEA AND VOMITING)
# TAB. VELOZ 40 MG 1 TAB ONCE DAILY FOR 7 DAYS (EMPTY STOMACH DAILY MORNING)
# POWDER PROGA 1 TSP IN HALF GLASS OF WATER TWICE DAILY FOR 10 DAYS
# SYP LOOZ 15 ML SOS FOR CONSTIPATION AT BEDTIME
# TAB. METROGYL ER 600 MG 1 TAB 4TIMES DAILY FOR 7 DAYS
# TAB. FARONEM ER 300MG 1 TAB TWICE DAILY FOR 7 DAYS (AFTER MEALS)
# TAB. CALPOL 650 MG 1 TAB SOS (FOR FEVER AND HEADACHE)
#
# VisitId: 2379618
# Matching Tests : ==>
# UROFLOWMETRY
#
# VisitId: 2379624
# Matching Medicines : ==>
# TAB PANTOP 40MG 1 TAB ONCE DAILY BEFORE BREAKFAST
# TAB. ALRISTA-SR 150 MG ONCE DIALY
# TAB. AMTAS 5 MG TWICE DAILY
# TAB. DEPRAN 10 MG AT NIGHT
# TAB. GABAPIN-NT 400/10 MG AT NIGHT
# TAB DUVITO ONE TAB TWICE DAILY
# SYP CREMAFIIN PLUS 20 ML BD FOR CONSTIPATION
# TAB. DUZELA 20 MG TWICE DAILY
#
# VisitId: 2379625
# Matching Medicines : ==>
# POWDER PEGLEC 2 BOX IN 4L WATER FORM 4-8 AM CM
#
# VisitId: 2379635
# Matching Medicines : ==>
# TAB. ULTRACET 1 TAB SOS
#
# VisitId: 2379650
# Matching Medicines : ==>
# TAB AUGMENTIN 625 MG 1 TDS
# TAB ALLEGRA 120 MG 1 OD
#
# VisitId: 2379667
# Matching Medicines : ==>
# TAB CLOPITAB 75 MG 1 HS AT BEDTIME  AFTER NEURO CLEARANCE
#
# VisitId: 2379667
# Matching Medicines : ==>
# TAB SATRPRESS XL 25 MG 1 OD 7.00AM
#
# VisitId: 2379676
# Matching Medicines : ==>
# TRAVOPROST EYE DROPS AT BEDTIME
# TAB WYSOLONE 40 MG ONCE DAILY AFTER FOOD
# TAB GLYCOMET SR 500 MG 1 TAB TWICE DAILY BEFORE FOOD
# TAB DIAMOX 250 MG 1/2 TAB TWICE DAILY AFTER FOOD
# FDC EYE DROP THRICE DAILY
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB AZURAN 50 MG ONCE DAILY AFTER FOOD
# CAPSULES RAPILIF - D 1 CAPSULE AT BEDTIME
# SYP CREMAFFIN PLUS 15 ML AT BEDTIME
# CAP PANTOCID DSR 1 CAP BEFORE BREAKFAST
# TAB THYROX 25 MCG 1 TAB BEFORE BREAKFAST
# TAB MIRBEG 25 MG 1 TAB AFTER DINNER
# TAB SYNDOPA PLUS 125 MG 4 TIMES A DAY 1 HOUR BEFORE FOOD
# TAB ROSUVAS 20 MG 1 TAB AFTER DINNER
# TAB PACITANE 2 MG 1/2 TAB TWICE DAILY AFTER FOOD
#
# VisitId: 2379687
# Matching Tests : ==>
# UROFLOWMETRY
#
# VisitId: 2379690
# Matching Tests : ==>
# SIGMOIDOSCOPY
#
# VisitId: 2379714
# Matching Tests : ==>
# UROFLOWMETRY
#
# VisitId: 2379727
# Matching Tests : ==>
# SPEECH THERAPY
# Matching Medicines : ==>
# TAB ECOSPRIN 75 MG 1 TAB ONCE DAILY AT BEDTIME TO CONTINUE
# TAB TELMA 40 MG 1 TAB ONCE DAILY IN MORNING
# SYP. LOOZ 20 ML AT BEDTIME FOR CONSTIPATION IF REQUIRED
# TAB. BRIVGARD 75 MG 1 TAB TWICE DAILY TO CONTINUE
# TAB. NOOTROPIL 800 MG 1 TAB. THRICE DAILY
# TAB BRILINCTA 90 MG 1 TAB TWICE DAILY TO CONITNUE
# TAB. VELOZ 20 MG 1 TAB TWICE DAILY (BEFORE MEALS)
# CAP. FELICITA OD 1 CAP. ONCE DAILY
#
# VisitId: 2379732
# Matching Medicines : ==>
# CAP AMANTREL 100 MG 1 CAP TWIEC DAILY AFTER FOOD
# TAB SYNDOPA 110 MG ½ TAB TWICE DAILY 1 HOUR BEFORE FOOD
# TAB INDERAL LA 40 MG 1 TAB AFTER DINNER
# TAB STALOPAM 5 MG 1 TAB AFTER DINNER
# TAB ET DONE 25 MG 1/2 TAB AFTER DINNER
# TAB DUVITO1 TAB TWICE DAILY AFTER FOOD
#
# VisitId: 2379747
# Matching Medicines : ==>
# TAB VERTIN 8 MG THRICE DAILY
# TAB NOOTROPIL 800 MG TWICE DAILY
# TAB DAYVIGO 10 MG AT BED TIME
# TAB CALZIVIA ONCE DAILY AFTER BF
#
# VisitId: 2379755
# Matching Medicines : ==>
# CAP VELOZ D 1 OD BBF
# TAB AZMARDA 50 MG 1/2 BID 7.00AM/PM
# TAB XAPILIS 5 MG 1 BID 7.00AM/PM
# TAB STORVAS 40 MG 1 HS
# TAB DYTOR PLUS LS 10/25 MG 1 OD
#
# VisitId: 2379755
# Matching Medicines : ==>
# TAB DAPARYL 10 MG 1 OD WITH LUNCH
#
# VisitId: 2379759
# Matching Tests : ==>
# SIGMOIDOSCOPY
#
# VisitId: 2379761
# Matching Tests : ==>
# CBC
# KFT
# HBA1C
# THYROID PROFILE
#
# VisitId: 2379764
# Matching Medicines : ==>
# TAB ENCORATE CHRONO 500 MG TWICE DAILY
# TAB LOBAZAM 10 MG ONCE DAILY AT 9 PM
#
# VisitId: 2379780
# Matching Tests : ==>
# USG SCROTUM
#
# VisitId: 2379786
# Matching Tests : ==>
# KFT
#
# VisitId: 2379795
# Matching Medicines : ==>
# TAB. ISOLAZINE ORALLY THRICE DAILY (7:00AM/2:00PM/8:00PM))
# TAB. UDAPA 10MG ORALLY ONCE DAILY (7:00AM)
# TAB. CONCOR 2.5NG ORALLY TWICE DAILY (10:00AM -10:00PM)
# TAB. PLANEP 25MG ORALLY ONCE DAILY (10:00AM)
# TAB. SILODAL 8MG ORALLY AT BED TIME ( 10:00PM)
# TAB. DYTOR 10MG ORALLY ONCE DAILY (10:00AM)
# TAB. ATORVA 40MG ORALLY ONCE DAILY AT BED TIME(10:00PM)
# LAXOPEG SACHET 17 GM DISOLVED IN ONE GLASS OF WATER
# TAB. VERQUVO 2.5MG ORALLY ONCE DAILY WITH LUNCH
# TAB. ELIQUIS 2.5 MG 1 BID 7.00AM/7.00PM
#
# VisitId: 2379795
# Matching Medicines : ==>
# TAB FEBUTAZ 40 MG ONCE DAILY AT 10.00AM
#
# VisitId: 2379797
# Matching Tests : ==>
# TSH
# HBA1C
# ECHO
# USG WHOLE ABDOMEN
# CALCIUM
# URINE R/M
# ECG
# LIPID PROFILE
# APTT
# RA FACTOR
# PT INR
# PSA
# KFT
# URINE R/M C/S
# ANTI HCV
# ESR
# CPK
# COMPLETE HGM
# TROP I
# LFT
# PERIPHERAL BLOOD FILM
# SR PSA FREE TOTAL
# CKMB
# PT INR APTT
# ANA - IF
# HBSAG
# INR
# Matching Medicines : ==>
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
# TAB DOXCEF CV TWICE DAILY 5 DAYS
# CAP D RISE 60 K ONCE WEEKLY 4 WEEKS
# CAP VELOZ 40 MG ONCE DAILY EMPTY STOMACH
# CAP VSL 3 ONCE DAILY 5 DAYS
# CAP NERVZ B ONCE DAILY - 15 DAYS
#
# VisitId: 2379818
# Matching Tests : ==>
# BLOOD SUGAR R
# Matching Medicines : ==>
# TAB QVM 10 I BD
# TAB ROSEDAY 10 MG 1 OD
# TAB ZORYL MI 1 OD
#
# VisitId: 2379819
# Matching Medicines : ==>
# TAB DILNIP 10 MG 1 BID
# TAB ONDERO MET 2.5 /500 MG 1 BID BEFORE BREAKFAST AND DINNER
# TAB RECLIDE XR 60 MG 1 OD BEFORE BREAKFAST
# TAB OLMEZEST CH 40/12.5 MG 1 OD 7.00AM
# CAP ECOSPRIN AV 75/40 MG 1 HS AT BEDTIME
# TAB SILODAL 8 MG 1 HS AT BEDTTIME
#
# VisitId: 2379823
# Matching Tests : ==>
# ECG
# Matching Medicines : ==>
# SYP LOOZ 15 CC HS
# TAB ROZUSTAT 40 HS
# TAB CLOPITAB A 75/75 BD
# TAB PAN DSR 40 OD
# TAB TAZLOC 40 OD
# TAB FLAVEDON MR 35 BD
#
# VisitId: 2379831
# Matching Medicines : ==>
# TAB CONCOR AM 5/5 MG 1 OD 7.0AM
#
# VisitId: 2379839
# Matching Tests : ==>
# HBA1C
# CBC
# LIPID PROFILE
# FBS
# RFT
# Matching Medicines : ==>
# TAB ROSUVA 40MG HS
# TAB TELMA 20 MG OD
# TAB. METHYLCOBALAMIN 1500 MG TAB FOR 1 MONTHS
# TAB ECOSPRIN 150 MG HS
# TAB DAPA 10MG ABF
# TAB CLOPID 75 MG BD
# TAB RANTAC 150 MG BD
# TAB BISONEXT 1.25MG OD
#
# VisitId: 2379844
# Matching Tests : ==>
# HBA1C
# UGIE/RUT
# CBC
# FIBROSCAN-LIVER
# LIPASE
# PERIPHERAL SMEAR FOR BLOOD PICTURE
# KFT
# LIPID PROFILE
# VITAMIN D
# B12
# LFT
# FIBROSCAN
# CRP
# THYROID PROFILE
#
# VisitId: 2379846
# Matching Medicines : ==>
# CAP BECOSULE Z 1 OD ABF
# TAB. DYTOR 5 MG 1 TAB ONCE DAILY MORNING AT 8:00AM
# TAB. PANTOCID 40 MG ORALLY ONCE DAILY BEFORE BREAKFAST
# TAB. GLYXAMBI 25/5 MG ONCE DAILY WITH LUNCH
# TAB PLANEP 25 MG ORALLY ONCE DAILY AT 10.00AM
# TAB. VYMADA 50 MG 1/2 TAB TWICE DAILY AT 7 AM / 7 PM
# TAB. IVABRAD 5 MG 1 TAB TWICE DAILY AFTER BREAKFAST AND DINNER
#
# VisitId: 2379846
# Matching Medicines : ==>
# TAB. BRILINTA 90 MG ORALLY TWICE DAILY (10:00 AM / 10:00 PM)
# TAB. ECOSPRIN 75 MG ORALLY ONCE DAILY AT BED TIME
# TAB. AZTOR 80 MG ORALLY ONCE DAILY AT BED TIME
#
# VisitId: 2379867
# Matching Medicines : ==>
# TAB SHELCAL 500 MG 1 TAB TWICE DAILY AFTER FOOD
# CAP PANTOCID DSR 1 CAP BEFORE BREAKFST
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB TOLPERITAS D 1 TAB SOS FOR PAIN
# TAB GABATOR NT 100 MG 1 TAB AFTER DINNER
# CAP DUZELA 30 MG 1 CAP AFTER DINNER
#
# VisitId: 2379868
# Matching Medicines : ==>
# CAP AMANTREL 100 MG 1 CAP TWICE DAILY AFTER MEAL
# SYRUP CREMAFFIN PLUS 20 ML AFTER DINNER
# TAB DEPRAN 10 MG 1 TAB AFTER DINNER
# TAB RASALECT 0.5 MG ONCE DAILY AFTER FOOD
# TAB PRAMIPEX 0.25 MG 1/2 TAB THRICE DAILY AFTER MEAL
# TAB ARICEP 5 MG 1 TAB AFTER BREAKFAST
# TAB SYNCAPONE 100 MG 1/2 TAB TWICE DAILY 1 HOUR BEFORE FOOD
# TAB ADMENTA 10 MG 1 TAB AFTER BREAKFAST
# TAB ELIQUIS 2.5 MG 1 TAB TWICE DILY AFTER MEAL
# TAB SYNDOPA PLUS 125 MG 1 TAB THRICE DAILY 1 HOUR BEFORE MEAL
#
# VisitId: 2379870
# Matching Medicines : ==>
# TAB DYTOR PLUS LS 10/25 MG 1 OD 7.00AM
#
# VisitId: 2379883
# Matching Medicines : ==>
# TAB PACITANE 2 MG 1/2 TAB TWIEC DAILY AFTER FOOD
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB DEPRAN 10MG 1 TAB AFTER DINNER
# TAB ADMENTA 10 MG 1 TAB AFTER BREAKFAST
# TAB ABEXIS 2.5 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB OLEANZ 2.5 MG 1/2 TAB AFTER DINNER
# TAB GALAMER 4 MG 1 TAB AFTER BREAKFAST
# TAB PANTOCID 40MG 1 TAB BEFORE BREAKFAST
# TAB STROCIT PLUS 500/800 MG 1 TAB TWICE DAILY AFTER FOOD
#
# VisitId: 2379886
# Matching Tests : ==>
# UROFLOWMETRY
#
# VisitId: 2379887
# Matching Medicines : ==>
# TAB. AZTOR 80 MG ORALLYONCE DAILY AT BED TIME
# TAB. VYMADA 100 MG 1 TAB TWICE DAILY AT 7 AM / 7 PM
# TAB. PANTOCID 40 MG ORALLYONCE DAILY BEFORE BREAKFAST
# TAB. BRILINTA 90 MG ORALLY TWICE DAILY (10:00 AM / 10:00 PM)
# TAB. ISOLAZINE 1 TAB TWICE DAILY AT 7 AM / 7 PM
# TAB. ECOSPRIN 75 MG ORALLYONCE DAILY AT BED TIME
# TAB. PLANEP 25 MG 1 TAB ONCE DAILY AT 10 AM
#
# VisitId: 2379887
# Matching Medicines : ==>
# TAB THYROX 75 MCG 1 OD EMPTY STOMACH
#
# VisitId: 2379896
# Matching Tests : ==>
# USG NECK
#
# VisitId: 2379908
# Matching Tests : ==>
# KFT
#
# VisitId: 2379911
# Matching Medicines : ==>
# TAB AZMARDA 100 MG BD
# TAB CONCOR 2.5 MG OD
# TAB ALDACTONE 25 MG OD
# TAB DAPA 10 MG ABF
# TAB PAN 40 MG OD
# TAB CLOPITAB- A 75/75 MG BD
# TAB ROZUSTAT 40 MG HS
#
# VisitId: 2379913
# Matching Medicines : ==>
# TAB STEMITIL 5 MG SOS
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB TOPAZ 25 MG 1 TAB AFTER DINNER
# TAB TRYPTOMER 10 MG 1 TAB AFTER DINNER
# TAB MAXGALIN 75 MG 1 TAB AFTER DINNER
# TAB NAXDOM 500 MG SOS FOR HEAD PAIN
# TAB VERTIN 24 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB DILIGAN 25 MG 1 TAB TWICE DAILY AFTER FOOD
#
# VisitId: 2379921
# Matching Medicines : ==>
# TAB GLIMY MV2 1 BID BEFORE BREAKFAST AND DINNER
# TAB DYTOR  10/MG 1 OD 7.00AM
# TAB CONCOR 2.5 MG 1 OD 7.00AM
# TAB ROSULIP 40 MG 1 HS AT BEDTIME
# TAB ISOLAZINE 1 BID 7.00AM/7.00PM
# TAB HEFCARD 50 MG 1 BID 7.00AM/7.00PM
# TAB PANTOCID 40 MG 1 OD BBF
# TAB TICASPAN 90 MG 1 BID 10.00AM/10.00PM
# TAB ECOSPRIN 75 MG 1 HS AT BEDTIME
#
# VisitId: 2379928
# Matching Medicines : ==>
# TAB. LEVIPIL 500MG 1 TAB TWICE DAILY TO CONTINUE
# TAB NAXDOM 500 MG TWICE DAILY
#
# VisitId: 2379947
# Matching Medicines : ==>
# TAB ECOSPRIN 75 MG 1 TAB AFTER DINNER
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB RIVOTRIL 0.5 MG SOS FOR ANXIETY
# TAB MIRTAZ 7.5 MG 1 TAB AFTER DINNER
# TAB ENCORATE CHRONO 500 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB GABATOR NT 100 MG  1TAB AFTER DINNER
# TAB STALOPAM 10 MG 1 TAB AFTER DINNER
# TAB TOLPERITAS D 1 TAB TWICE DAILY AFTER FOOD FOR 2 DAYS
# TAB OLEANZ 2.5 MG 1/2 TAB AFTER DINNER
# TAB PANTOCID 40 MG 1 TAB BEFORE BREAKFAST
# CAP DUZELA 30 MG 1 CAP AFTER DINNER
#
# VisitId: 2379957
# Matching Medicines : ==>
# TAB ECOSPIRIN AV 150/20 MG 1 TAB AT BED TIME
# TAB DYTOR PLUS 10 ONCE DAILY
# TAB HOMOCHECK 1 TAB TWICE DAILY AFTER FOOD
# TAB AMLONG 5MG 1 TAB ONCE DAILY AFTER FOOD
# TAB ELIQUIS 5 MG TWICE DAILY AFTER FOOD
# TAB PANTOCID 40 MG 1 TAB ONCE DAILY (BEFORE BREAKFAST)
#
# VisitId: 2379959
# Matching Tests : ==>
# HBA1C
# ANTI HCV
# UGIE/RUT
# CBC
# FIBROSCAN-LIVER
# LIPASE
# PERIPHERAL SMEAR FOR BLOOD PICTURE
# KFT
# LIPID PROFILE
# VITAMIN D
# COLONOSCOPY
# B12
# LFT
# HBSAG
# FIBROSCAN
# CRP
# THYROID PROFILE
#
# VisitId: 2379964
# Matching Medicines : ==>
# THEN 1 - 1/2 - 1 TAB FOR 5 DAYS
# CAP DUZELA 30 MG 1 CAP TWICE DAILY AFTER FOOD
# SYRUP CREMAFFIN PLUS 10 ML AFTER DINNER
# TAB OROFER XT 1 TAB AFTER BREAKFAST
# TAB SHELCAL 500 MG 1 TAB TWICE DAILY AFTER FOOD
# THEN 1 TAB ONCE DAILY FOR 5 DAYS
# THEN 1 TAB MORNING & 1/2 TAB NIGHT FOR 5 DAYS
# THEN 1/2 TAB ONCE DAILY FOR 5 DAYS
# TAB PANTOCID 40 MG 1 TAB BEFORE BREAKFAST
# TAB CABGOLIN 0.5 1 TAB ONCE DAILY AFTER FOOD
# TAB ECOSPRIN AV 75/20 MG 1 TAB AFTER DINNER
# TAB MIRTAZ 7.5 MG 1 TAB AFTER DINNER
# TAB PRAMIPEX 0.5 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB PENTANEREV NT 400 MG 1 TAB AFTER DINNER
# LAXOPEG SACHET AFTER DINNER WITH MILK
# TAB MEDROL 16 MG 1 TAB THRICE DAILY FOR 5 DAYS
# THEN 1 TAB TWICE DAILY FOR 5 DAYS
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB EVION LC 1 TAB AFTER DINNER
# TAB ALRISTA -SR 150 MG 1 TAB AFTER BREAKFAST
#
# VisitId: 2379974
# Matching Tests : ==>
# TSH
# HBA1C
# SR PSA FREE TOTAL
# ESR
# PSA
# URINE R/M
# COMPLETE HGM
# ECG
# KFT
# LIPID PROFILE
# FBS
# LFT
# PPBS
# Matching Medicines : ==>
# TAB URIMAX D 0.5 MG 1TAB ONCE DAILY NIGHT AS PER UROLOGY
# TAB JANUMET 50/500 MG 1TAB TWICE DAILY AFTER BREAKFAST AND DINNER
# TAB ERITEL 40 MG ONCE DAILY MORNING
# TAB. THYROX 37.5 ( 25 + 12.5 ) MCG ONCE DAILY (BEFORE BREAKFAST )
# TAB ROSUVAS 5 MG 1TAB ONCE DAILY NIGHT
#
# VisitId: 2379977
# Matching Tests : ==>
# SPEECH THERAPY
# Matching Medicines : ==>
# TAB LACOSAM 100 MG 1 TAB TWICE DAILY TO CONTINUE
# TAB. EPIFAST  1 GM 1 TAB TWICE DAILY TO CONTINUE
# CAP. REJUNEX CD3 1 TAB ONCE DAILY
# SYP. LOOZ 20ML AT BEDTIME FOR CONSTIPATION IF REQUIRED
# TAB TAB TELSARTAN AM 40+5 MG 1 TAB TWICE DAILY
# TAB CTD 12.5 MG 1 TAB ONCE DAILY
# TAB. VELOZ 20 MG 1 TAB TWICE DAILY BEFORE MEALS
# TAB ARKAMINE 0.1 MG 1 TAB THRICE DAILY
#
# VisitId: 2379994
# Matching Medicines : ==>
# TAB NOOTROPIL 800 MG TWICE DAILY
# TAB ESLIZEN 400 MG TWICE DAILY
# TAB GABAPIN 200 MG TWICE DAILY
#
# VisitId: 2380017
# Matching Tests : ==>
# ECHO
# CBC
# KFT
# B12
# LFT
#
# VisitId: 2380018
# Matching Medicines : ==>
# TAB. LEVERA 250MG 1 TAB TWICE DAILY FOR 14 DAYS THEN
# TAB. LEVERA 250MG 1 TAB ONCE DAILY FOR 14 DAYS THEN STOP
# TO RESTART TAB LEVERA 500MG 1 TAB TWICE DAILY IF ANY SEIZURE ACTIVITY
#
# VisitId: 2380021
# Matching Medicines : ==>
# TAB NEXITO PLUS 1 TAB AFTER DINNER
# TAB INDERAL LA 40 MG 1 TAB AFTER DINNER
# TAB HOMOCHECK 1 TAB TWICE DAILY AFTER FOOD
# TAB PETRIL MD 0.25 MG SOS FOR ANXIETY
# TAB ETIZOLA BETA 0.5 MG 1 TAB AFTER DINNER
# TAB SYNDOPA PLUS 125 MG 1 TAB THRICE DAILY 1 HOUR BEFORE FOOD
# TAB MIRTAZ 7.5 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB OLEANZ 2.5 MG 1/2 TAB AFTER DINNER
# TAB ETDONE 25 MG1 TAB AFTER DINNER
# TAB PANTOCID 40 MG 1 TAB BEFORE BREAKFAST
# CAP DUVITO 1 CAP TWICE DAILY AFTER FOOD
# TAB PACITANE 2 MG 1/2 TAB TWICE DAILY AFTER FOOD
#
# VisitId: 2380028
# Matching Tests : ==>
# HBA1C
# CBC
# LIPASE
# PERIPHERAL SMEAR FOR BLOOD PICTURE
# KFT
# VITAMIN D
# B12
# LFT
# CRP
# THYROID PROFILE
#
# VisitId: 2380036
# Matching Medicines : ==>
# TAB PETRIL 0.25 MG SOS FOR ANXIETY AND SLEEP
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB LACOSAM 100MG ONE TAB TWICE DAILY  AFTER FOOD
# TAB MOZEP 2 MG 1 TAB AFTER DINNER
# TAB NEXITO 5 MG 1 TAB AFTER DINNER
# TAB VALPROATE CR 500 MG ONE TAB TWICE DAILY AFTER FOOD
# TAB NITREST 1 TAB 5 MG 1 TAB AFTER DINNER
# TAB CILENTRA 10 MG 1 TAB AFTER DINNER
# TAB PANTOP 40 MG 1 TAB BEFORE BREAKFAST
# SYP LOOZ 20 ML AFTER DINNER
# TAB BRIV 50 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB GLYCOMET SR 500 MG 1 TAB TWICE DAILY BEFORE FOOD
# TAB PECITANE 2 MG 1/2 TAB TWICE DAILY  AFTER FOOD
# TAB SYNDOPA 110 MG 1/4 TH TAB TWICE DAILY 1 HOUR BEFORE FOOD
#
# VisitId: 2380037
# Matching Medicines : ==>
# TAB GABAPIN 200 MG TWICE DAILY
# TAB EZACT MR 60 MG SOS FOR PAIN
# TAB PANTOP 40 MG ONCE DAILY BBF
# SYP PICOFINE 15 - 20 ML DAILY AT BED TIME
# TAB CALZIVIA ONCE DAILY AFTER BF
#
# VisitId: 2380041
# Matching Tests : ==>
# CBC
# LIPASE
# LFT
# CRP
#
# VisitId: 2380048
# Matching Tests : ==>
# HBA1C
# CBC
# KFT
# LIPID PROFILE
# LFT
#
# VisitId: 2380050
# Matching Tests : ==>
# UROFLOWMETRY
#
# VisitId: 2380055
# Matching Medicines : ==>
# TAB DOLO 650 MG 1 TAB THRICE DAILY SOS FOR HEADAVHE OR PAIN
# TAB. VELOZ D 1 TAB ONCE DAILY (BEFORE MEALS)
# TAB LACOSAM 50 MG 1 TAB TWICE DAILY TO CONTINUE
# CAP. FELICITA OD 1 CAP. ONCE DAILY FOR 10 DAYS
# TAB CALZIVIA 1 TAB ONCE DAILY AFTER BREAKFAST
# SYP. LOOZ 30 ML AT BEDTIME FOR CONSTIPATION
# TAB. EPILIVE 1 GM 1 TAB TWICE DAILY TO CONTINUE
#
# VisitId: 2380070
# Matching Tests : ==>
# USG NECK
# HBA1C
# Matching Medicines : ==>
# TAB ROSUVAS F 10+160 MG ONCE DAILY NIGHT
# TAB VOLIBO 0.3 MG THRICE DAILY BEFORE MEALS
# TAB AMARYL 1 MG ONCE DAILY BEFORE BREAKFAST
# TAB ONDEROMET 2.5/1000 MG 1 TAB TWICE DAILY AFTER BREAKFAST AND DINNER
#
# VisitId: 2380085
# Matching Medicines : ==>
# SYP BROZEDEX 2 TSF TDS
# TAB DYTOR PLUS LS 10/25 MG 1 OD 7.00AM
# TAB CETIL CV 1 BID
#
# VisitId: 2380087
# Matching Tests : ==>
# CBC
# KFT
# BLOOD SUGAR R
# LFT
#
# VisitId: 2380091
# Matching Medicines : ==>
# CAP PANTOCID DSR 1 OD BBF
#
# VisitId: 2380094
# Matching Tests : ==>
# FIBROSCAN-LIVER
# FIBROSCAN
#
# VisitId: 2380095
# Matching Medicines : ==>
# TAB BRIV 75 MG TWICE A DAY AFTER FOOD
# TAB ECOSPRIN AV 75/20 MG 1 TAB AFTER DINNER
# TAB TELMA 40 MG ONCE DAILY AFTER FOOD
# TAB DEPRANEX 5 MG 1 TAB AFTER DINNER
# GEMCAL NASAL SPRAY ALTERNATE NOSETRAIL
# TAB HOMOCHEK 1 TAB TWICE DAILY AFTER FOOD
# CAP AMANTREL 100 MG TWICE DAILY AFTER FOOD
# TAB ELIQUIS 2.5 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB PEXEP CR 12.5 MG 1 TAB AFTER DINNER
# TAB OROFER XT 1 TAB AFTER BREAKFAST
# TAB PANTOCID 40 MG 1 TAB BEFORE BREAKFAST
# TAB PETRIL-MD 0.25 MG SOS FOR ANXIETY
# TAB OSTEOPHOS 70 MG 1 TAB ONCE A WEEK BEFORE BREAKFAST & WALK FOR 15 MIN
#
# VisitId: 2380096
# Matching Tests : ==>
# HBA1C
# ECHO
# CBC
# KFT
# LIPID PROFILE
# LFT
# Matching Medicines : ==>
# • INJ GEMCITABINE 1 GM/M2 DAY 1 AND DAY 8
# • INJ CARBOPLATIN AU 2.5 DAY 1 AND DAY 8
#
# VisitId: 2380125
# Matching Medicines : ==>
# TAB SOMPRAZ D 1 BD
# TAB UDILIV 300 MG 1 TDS
# TAB FARONEM 200 MG 1 BD
# TAB PEXEP CR 12.5 MG 1 HS
#
# VisitId: 2380126
# Matching Tests : ==>
# SPEECH THERAPY
# Matching Medicines : ==>
# TAB. VELOZ 40 MG 1 TAB TWICE DAILY (BEFORE MEALS)
# TAB BRIVGARD 75 MG 1 TAB TWICE DAILY TO CONTINUE
# SYP. DIGENE 2TSF TWICE DAILY
# TAB. GABAPIN NT 100/10 1 TAB ONCE DAILY AT BEDTIME
# TAB FABUTAZ 40 MG 1 TAB ONCE DAILY
# SYP. LOOZ 20 ML AT BEDTIME FOR CONSTIPATION IF REQUIRED
# TAB. GABAPIN 100MG ONCE DAILY
# CAP GINKOCER PLUS 1 CAP ONCE DAILY
#
# VisitId: 2380130
# Matching Tests : ==>
# HBA1C
# CBC
# KFT
# LIPID PROFILE
# LFT
#
# VisitId: 2380138
# Matching Medicines : ==>
# TAB MOXOVAS 0.3 MG 1 BID 7.00AM 7.00PM
# TAB CONCOR 2.5 MG 1 BID 7.00AM/7.00PM
# TAB PANTOCID 40 MG 1 OD BBF
# TAB OLMEZEST CH 40/12.5 MG 1 OD 7.00AM
# CAP ECOSPRIN AV 75/40 MG 1 HS AT BEDTIME
#
# VisitId: 2380138
# Matching Medicines : ==>
# TAB MINIPRES XL 2.5 MG 1 OD AT NIGHT
#
# VisitId: 2380140
# Matching Medicines : ==>
# TAB CARDIVAS 6.25 MG 1 TAB BD( 7 AM /7 PM)
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB AMANTREL 100 MG TWICE DAILY AFTER FOOD
# SYRUP CREMAFFIN PLUS 15 ML AFTER DINNER
# TAB ECOSPRIN AV 75/40 G 1 TAB AFTER DINNER
# TAB LEVIPIL 750 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB PANTOP 40 MG 1 TAB BEFORE BREAKFAST
# TAB AZMARDA 50 MG 1 TAB TWICE DAILY ( 7 AM/7 PM)
# TAB PRAMIPEX 0.25 MG 1/2 TAB AFTER DINNER
# TAB ABAXIS 2.5 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB SYNDOPA 110 MG 1/2 TAB THRICE DAILY 1 HR BEFORE FOOD
#
# VisitId: 2380141
# Matching Tests : ==>
# HRCT CHEST
#
# VisitId: 2380142
# Matching Medicines : ==>
# TAB CLOPITAB  75MG ORALLY ONCE DAILY
# TAB PANTOP 40MG ONCE DAILY BEFORE BREAKFAST
#
# VisitId: 2380142
# Matching Medicines : ==>
# TAB LINID 600 MG BD - 5 DAYS.
# TAB VIZYLAC 1 BD - 10 DAYS
#
# VisitId: 2380145
# Matching Tests : ==>
# CBC
# KFT
# LFT
# Matching Medicines : ==>
# CAP PANTOCID IT ONCE DAILY BEFORE BREAKFAST
# SYP LOOZ 15 ML AT BEDTIME 9CONSTIPATION)
# TAB LIBRAX 1 TABLET TWICE DAILY AFTER FOOD
# TAB ZENTEL 400 MG ONCE DAILY X 3 DAYS
# CAP GUTFRIEND 1 CAPSULE TWICE DAILY AFTER FOOD X 10 DAYS
# TAB EMESET 4 MG BEFORE LUNCH/ DINNER
#
# VisitId: 2380146
# Matching Tests : ==>
# HBA1C
# CBC
# KFT
# LIPID PROFILE
# B12
# LFT
# THYROID PROFILE
#
# VisitId: 2380147
# Matching Medicines : ==>
# TAB REVELOL 50 MG 1 OD 7.00PM
# TAB TELMA LN 40 MG 1 OD 7.00AM
# TAB NATRILIX SR 1.5 MG 1 OD 7.00AM
#
# VisitId: 2380180
# Matching Medicines : ==>
# TAB OSTEOFOS 70 MG 1 TAB ONCE A WEEK
# CALIROL SACHET ONCE A MONTH
# TAB PETRIL MD 0.25 MG SOS FOR ANXIETY
# TAB GABAPIN NT 400 MG 1 TAB AFTER DINNER
# TAB TOPAZ 25 MG 1 TAB AFTER DINNER
# TAB LUPIRTIN SR 150 MG 1 TAB TWICE DAILY AFTER MEAL
# TAB TRYPTOMER 10 MG 1 TAB AFTER DINNER
# CAP PANTOCID DSR 1 CAP BEFORE BREAKFAST
# TAB STALOPAM 10 MG1 TAB AFTER DINNER
# TAB SHELCAL 500 MG 1 TAB AFTER BREAKFAST
# TAB DIVAA OD 250 MG 1 TAB AFTER DINNER
# TAB NAXDOM 500 MG SOS FOR HEAD PAIN
# CAP REJUNEX OD 1 CAP AFTER BREAKFAST
#
# VisitId: 2380184
# Matching Tests : ==>
# CBC
# INR
# LFT
# KFT
# Matching Medicines : ==>
# CAP ZEVIT ONCE A DAY
# SYP LOOZ 30ML AT BEDTIME
# TAB RIGAGUT 550MG TWICE A DAY
# TAB PANTOCID 40MG ONCE A DAY
# TAB BENALGIS 100MG ONCE A DAY
# TAB TRENTAL 400MG THRICE A DAY
#
# VisitId: 2380193
# Matching Tests : ==>
# VITAMIN B12
# HBA1C
# CBC
# ESR
# ECG
# KFT
# LIPID PROFILE
# VITAMIN D
# B12
# LFT
# THYROID PROFILE
#
# VisitId: 2380197
# Matching Medicines : ==>
# TAB. ISOLAZINE 1 TABLET ORALLY THRICE DAILY
# CAP. VIZYLAC 1 CAPSULE ORALLY TWICE DAILY
# TAB. PANTOCID 40 MG ORALLY ONCE DAILY BEFORE BREAKFAST
# TAB. DILNIP 10 MG ORALLY TWICE DAILY (7:00 AM/ 7:00 PM)
# TAB. PRODIGUT 90 K ONCE DAILY
# TAB. LINAGLIPTIN 5 MG ORALLY ONCE DAILY WITH LUNCH
# TAB. DYTOR 20 MG ORALLY ONCE DAILY (8:00 AM)
# TAB CARDIVAS 3.125 MG 1 BID 7.00AM/7.00PM
# TAB. AMARYL 1 TABLET ORALLY ONCE DAILY BEFORE BREAKFAST
# TAB APLAZAR 2 TAB THRICE DAILY
# CAP. ECOSPRIN AV 75/40MG ORALLY AT BEDTIME
# TAB. MOXOVAS 0.3 MG ORALLY THRICE DAILY (7:00 AM/ 2:00 PM/ 8:00 PM)
#
# VisitId: 2380203
# Matching Tests : ==>
# KFT
#
# VisitId: 2380204
# Matching Tests : ==>
# CBC
# TSH
# LFT
#
# VisitId: 2380207
# Matching Medicines : ==>
# TAB ABAXIS5 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB DUVITO ONE TAB TWICE DAILY AFTER FOOD
# TAB PANTOP 40 MG 1 TAB BEFORE BREAKFAST.
# TAB DEPRAN 10 MG 1TAB AFTER DINNER
# TAB HOMOCHECK 1 TAB TWICE DAILY AFTER FOOD
# TAB TELMA 40 ONE TAB ONCE DAILY AFTER BREAKFAST
# TAB MIRTAZ 7.5MG ONE TAB AFTER DINNER
# TAB ECOSPRIN AV 75/10 MG 1 TAB AFTER DINNER
#
# VisitId: 2380214
# Matching Tests : ==>
# TSH
# HBA1C
# ECHO
# USG WHOLE ABDOMEN
# CALCIUM
# URINE R/M
# ECG
# LIPID PROFILE
# APTT
# B12
# DEXA SCAN WHOLE BODY
# RA FACTOR
# PT INR
# PSA
# KFT
# FBS
# MRI BRAIN
# SUGAR CHARTING WITH GLUCOMETER
# PPBS
# ANTI HCV
# ESR
# FUNDUS AND REFRACTION
# CPK
# COMPLETE HGM
# TROP I
# LFT
# PERIPHERAL BLOOD FILM
# WHOLE SPINE SCREENING
# HOLTER
# SR PSA FREE TOTAL
# CKMB
# PT INR APTT
# ANA - IF
# HBSAG
# INR
# Matching Medicines : ==>
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
# TAB ZENTAL 400 MG 1 TAB STAT DOSE TONIGHT ONLY
# CAP D RISE 60 K ONCE WEEKLY 4 WEEKS
# CAP VELOZ 40 MG ONCE DAILY EMPTY STOMACH
# CAP ABETANEURON D3 ONCE DAILY - 15 DAYS
#
# VisitId: 2380227
# Matching Medicines : ==>
# CONCURRENT CHEMOTHERAPY WITH INJECTION CISPLATIN WEEKLY X 5 SESSIONS
#
# VisitId: 2380230
# Matching Tests : ==>
# ESR
# URINE R/M
# COMPLETE HGM
# FBS
# URINE R/M C/S
# PERIPHERAL BLOOD FILM
# SUGAR CHARTING WITH GLUCOMETER
# PPBS
# THYROID PROFILE
# Matching Medicines : ==>
# CAP NERVZ B ONCE DAILY 1 MONTH
# TAB ERITEL 40 MG ONCE DAILY MORNING
# TAB JANUMET 50/500 MG TWICE DAILY AFTER BREAKFAST AND DINNER
# TAB AMARYL 1 MG ONCE DAILY BEFORE BREAKFAST
# SEROFLO INHALER MDI 2 PUFFS TWICE DAILY 15 DAYS
# TAB ALLEGRA 180 MG ONCE DAILY NIGHT 5 DAYS
# TAB. CALPOL 650 MG 1 TAB SOS (FOR FEVER AND HEADACHE)
# CAP PAN 40 MG ONCE DAILY EMPTY 10 DAYS
# TAB THYROXINE 125 MCG 1 TAB BEFORE BREAKFAST ( 30 MINUTES )
#
# VisitId: 2380232
# Matching Tests : ==>
# LIPID PROFILE
#
# VisitId: 2380238
# Matching Tests : ==>
# HBA1C
# CBC
# LIPASE
# ECG
# KFT
# LFT
# HBSAG
# INR
# CRP
# Matching Medicines : ==>
# INJ. DYNAPOAR 1 AMP IV 8 HRLY.
# INJ. N SALINE (100 ML/HR) IV
# INJ. PANTOCID (40 MG ) IV ONCE DAILY.
# INJ. TRAMADOL 50 MG IV AS REQUIRED WITH INJ. EMESET 4 MG)
# INJ. MONOCEFF 1 GM ) IV 12 HRLY.
# INJ. EMESET 4 MG IV 6 HRLY.MONITOR VITALS. INFORMAS REQUIRED.
#
# VisitId: 2380243
# Matching Tests : ==>
# TSH
# HBA1C
# ECHO
# USG WHOLE ABDOMEN
# CALCIUM
# URINE R/M
# ECG
# LIPID PROFILE
# APTT
# B12
# RA FACTOR
# PT INR
# PSA
# KFT
# MRI BRAIN
# ANTI HCV
# ESR
# CPK
# COMPLETE HGM
# TROP I
# LFT
# PERIPHERAL BLOOD FILM
# SR PSA FREE TOTAL
# CKMB
# LIPASE
# PT INR APTT
# ANA - IF
# HBSAG
# INR
# Matching Medicines : ==>
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
# CAP D RISE 60 K ONCE WEEKLY 4 WEEKS
# CAP VELOZ 40 MG ONCE DAILY EMPTY STOMACH
# SYP APTIVATE 1 TSP TWICE DAILY 5 DAYS
# CAP NERVZ B ONCE DAILY - 15 DAYS
#
# VisitId: 2380252
# Matching Medicines : ==>
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB LEVIPIL 750 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB PANTOP 40 MG 1 TAB BEFORE BREAKFAST
# TAB THYRONORM 88 MCG 1 TAB BEFORE BREAKFAST
# TAB TELMA 40 MG 1 TAB ONCE DAILY IF BP &GT130/90 MMHG AFTER BREAKFAST
#
# VisitId: 2380257
# Matching Medicines : ==>
# TAB DILZEM CD 90 MG 1 OD
# TAB DYTOR 5 MG 1 OD ON ALTERNATE DAYS
# TAB ELIQUIS 2.5 MG 1 BID
# TAB ISOLAZINE 1 BID 7.00AM/PM
# TAB PANTOCID 40 MG 1 OD BBF
#
# VisitId: 2380257
# Matching Medicines : ==>
# TAB AZMARDA 50 MG 1 BID 7.00AM/7.00PM
#
# VisitId: 2380262
# Matching Medicines : ==>
# TAB AMTAS 5 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB ECOSPRIN-AV 75/20MG 1 TAB AFTER DINNER
# TAB BRIV 75 MG ONE TAB TWICE DAILY AFTER FOOD
# TAB CARIDVAS XR 10 MG ONCE DAILY AFTER FOOD
# TAB PANTOP 40MG ONE TAB BEFORE BREAKFAST
# TAB GANATON TOTAL 40/150 30 MIN BEFORE BREAKFAST
# TAB ONDEM 4MG ONE TAB SOS FOR VOMITTING
# TAB FOLVITE  5 MG ONCE DAILY AFTER DINNER
#
# VisitId: 2380273
# Matching Medicines : ==>
# T.ZERODOL P 1 TAB AS REQUIRED FOR PAIN.
#
# VisitId: 2380288
# Matching Tests : ==>
# TSH
# HBA1C
# ANTI HCV
# RA FACTOR
# ESR
# URINE R/M
# COMPLETE HGM
# ECG
# LIPID PROFILE
# KFT
# LFT
# HBSAG
# PERIPHERAL BLOOD FILM
# Matching Medicines : ==>
# TAB. VELOZ 40 MG 1 TAB ONCE DAILY SOS FOR 5 DAYS (EMPTY STOMACH DAILY MORNING)
# TAB COMBUTOL 1200 MG ONE TAB ONCE DAILY IN MORNING AFTER BREAKFAST
# TAB ONDERO-MET 2.5/500 MG TWICE DAILY (AFTER BREAKFAST/AFTER DINNER)
# TAB ERITEL LN (40/10) ONCE DAILY IN MORNING
# CAP RCINEX (600/300) ONE TAB ONCE DAILY BEFORE BREAKFAST
# CAP. NERVZ B ONCE DAILY 15 DAYS
# TAB AMARYL 1 MG ONCE DAILY IN MORNING
# TAB FABUTAZ 40 MG ONCE DAILY NIGHT
# TAB. CALPOL 650 MG 1 TAB SOS (FOR FEVER AND HEADACHE)
# TAB LN BLOC 10 MG ONCE DAILY AT NIGHT &GT 140/80 MMHG
# TAB BENADON 40 MG 1/2 ONCE DAILY (IN MORNING)
# TAB PYRIZINAMIDE ( 1250 ) 750+500 MG ONE TAB IN MORNING AFTER BREAKFAST
#
# VisitId: 2380305
# Matching Medicines : ==>
# TAB LACOSAM 150 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# THEN 1 TAB TWICE DAILY
# TAB CALBOZIN 1 TAB TWICE DAILY AFTER FOOD
# TAB LEVIPIL 750 MG 1TAB TWICE DAILY AFTER FOOD
# CAP PANTOCID DSR 1 CAP BEFORE BREAKFAST
# TAB WYSOLON 10 MG 1 TAB ONCE DAILY AFTER FOOD FOR 7 DAYS
# TAB GRAVITOR 60 MG 1/2 TAB TWICE DAILY AFTER FOOD
#
# VisitId: 2380315
# Matching Medicines : ==>
# TAB DEPRAN 10 MG 1 TAB AFTER DINNER
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB PETRIL MD 0.25 MG SOS FOR ANXIETY
# TAB TOPAZ 25 MG 1 TAB AFTER DINNER
# TAB TRYPTOMER 10 MG 1 TAB AFTER DINNER
# TAB NAXDOM 500 MG SOS FOR HEAD PAIN
#
# VisitId: 2380329
# Matching Medicines : ==>
# TAB ZENOXA OD 150 MG 1 TAB AFTER DINNER FOR 3 DAYS
# TAB GABAPIN NT 100 MG 1 TAB AFTER DINNER
# CAP AMANTREL 100 MG 1 CAP TWICE DAILY AFTER FOOD
# TAB SYNAPTOL  150 MG 1 TAB TWICE DAILY AFTER FOOD
#
# VisitId: 2380335
# Matching Medicines : ==>
# TAB ECOSPRIN AV 75/20 MG 1 TAB AFTER DINNER
# TAB STARPRESSXL 50MG 1 TAB ONCE DAILY
# TAB ABAXIS 5 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB ADMENTA 10MG 1 TAB AFTER BREAKFAST
# TAB GALAMER 4 MG 1 TAB AFTER BREAKFAST
# TAB CARTIGEN FORTE ONCE DAILY
# TAB HIFINAC SR SOS FOR KNEE PAIN
#
# VisitId: 2380338
# Matching Tests : ==>
# LIPID PROFILE
#
# VisitId: 2380348
# Matching Tests : ==>
# HBA1C
# USG WHOLE ABDOMEN
# ECHO
# CBC
# URINE R/M
# DEXA SCAN 3 SITES
# CALCIUM
# ECG
# KFT
# LIPID PROFILE
# LFT
# THYROID PROFILE
# Matching Medicines : ==>
# TAB CALCIUM 500 MG 1 TAB ONCE DAILY
# TAB ATOZ 1 TAB ONCE DAILY
# TAB NUROKIND GOLD 1 TAB ONCE DAILY
# TAB D RISE 60 K ONCE WEEKLY
#
# VisitId: 2380375
# Matching Tests : ==>
# HBA1C
# URINE ROUTINE AND CULTURE
# CBC
# PSA
# LFT
# RFT
# Matching Medicines : ==>
# TAB SOMPRAZ 40 MG TWICE DAILY BEFORE FOOD
# TAB LIBRAX 1 TABLET TWICE DAILY AFTER FOOD
# TAB NIZONIDE 500 MG TWICE DAILY AFTER FOOD X 5 DAYS
#
# VisitId: 2380389
# Matching Tests : ==>
# ANTI HCV
# RA FACTOR
# ECHO
# ECG
# LIPID PROFILE
# FIBROSCAN
# HBSAG
# Matching Medicines : ==>
# CAP VELOZ 40 MG ONCE DAILY EMPTY STOMACH 10 DAYS
# CAP ABETANEURON D3 ONCE DAILY - 30 DAYS
# CAP D RISE 60 K ONCE WEEKLY 4 WEEKS
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
#
# VisitId: 2380393
# Matching Medicines : ==>
# TAB CALBOZIN 1 TAB TWIEC DAILY AFTER FOOD
# SYP CREMAFFIN PLUS 15 ML AFTER DINNER
# TAB ALPHACEPT 8 MG 1 TAB ONCE DAILY AFTER DINNER
# TAB SYNAPTOL 150 MG 1 TAB ONCE DAILY AFTER FOOD
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB ARICEP 5 MG ONCE DAILY AFTER BREAKFAST
# TAB AMENTRAL 100 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB ADMENTA 10 MG 1 TAB ONCE DAILY AFTER BREAKFAST
# TAB SYNDOPA PLUS 125 MG 1 TAB 6TH HOURLY
# TAB PANTOP 40 MG 1 TAB ONCE DAILY BEFORE BREAKFAST
# TAB SOLICEPT 5 MG 1 TAB ONCE DAILY AFTE DINNER
#
# VisitId: 2380400
# Matching Tests : ==>
# HBA1C
# USG WHOLE ABDOMEN
# CBC
# KFT
# LFT
# THYROID PROFILE
#
# VisitId: 2380402
# Matching Tests : ==>
# ECHO
# CBC
# BLOOD SUGAR R
# ECG
# KFT
# LFT
# Matching Medicines : ==>
# TAB QVM 10 1 BD
# TAB PANTOCID DSR 1 BD
# INSTARAFT SYP 2 TSF TDS
#
# VisitId: 2380406
# Matching Medicines : ==>
# INJ ZOLADEX 10.8 MG SC/IM - CODE 1276 ; NEEDS DAYCARE ADMISSION ; MEDICAL PER DAY PACKAGE 7 SUPPORTIVE CARE ; HOSPITAL WILL PROVIDE THE MEDICATIONS
#
# VisitId: 2380408
# Matching Medicines : ==>
# TAB BISONEXT 2.5 OD
# TAB CLOPITAB 75 OD
# TAB ZYROVA 40 HS
# TAB PANTOCID 40 OD
# TAB ECOSPRIN 150 OD
# TAB ISTAMET DXR 10/100/1000 OD
# TAB TAZLOC 40 OD
#
# VisitId: 2380416
# Matching Medicines : ==>
# TAB LIBRAX 1 TABLET TWICE DAILY AFTER FOOD
# TAB ZENTEL 400 MG STAT
# TAB REDROL 20 MG BEFORE BREAKFAST
# TAB DROTIN M 1 SOS FOR PAIN ABDOMEN
# SYP PEGALUP 25 ML AT BEDTIME WITH FULL GLASS OF WATER X 6 WEEKS
#
# VisitId: 2380425
# Matching Tests : ==>
# SIGMOIDOSCOPY
#
# VisitId: 2380429
# Matching Medicines : ==>
# CAP VELOZ D 1 OD BBF
# TAB IVABRAD 5 MG 1 BID 7.00AM/7.00PM
# TAB DYTOR 20 MG 1 OD 10 .00AM
# TAB PLANEP 25 MG 1 OD 7.00AM
# TAB AZMARDA 50 MG 1 BID 7.00AM/7.00PM
# CAP ROSEDAY GOLD 75/75/20 MG 1 HS AT BEDTIME
#
# VisitId: 2380432
# Matching Medicines : ==>
# TAB. DIGOXIN 0.125MG HALF TAB ONCE DAILY.(5DAYS IN A WEEK)(HOLD IF HEART RATE LESS THAN 60)
# TAB. ACITROM  1 MG ONCE  DAILY AT 6PM.
# TAB BECOSULE 1 OD.
# TAB. PANTOCID D 1 TAB ONCE DAILY 7AM BEFORE BREAKFAST
# TAB. DYTOR 10MG 1 TAB AND 5 MG IN EVENING DAILY. 9AM AND 4PM
#
# VisitId: 2380433
# Matching Medicines : ==>
# TAB ELIQUIS 2.5MG ORALLY TWICE DAILY AFTER FOOD
# TAB. ULTRACET P ORALLY SOS
# TAB. PANTOP 40MG ONCE DAILY BEFORE BREAKFAST
# TAB ECOSPRIN 75MG ONCE DAILY AT NIGHT AFTER FOOD
#
# VisitId: 2380439
# Matching Tests : ==>
# CBC
# BLOOD SUGAR R
# KFT
# TYPHI DOT IGM
# LFT
# Matching Medicines : ==>
# TAB CALPOL 650 MG 1 SOS TAB SOMPRAZ D 1 BD
# TAB MONDELESOR 1 OD
# TAB CEFURIC CV 625 MG 1 BD
#
# VisitId: 2380451
# Matching Medicines : ==>
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB GLIZID XR 60 MG 1 TAB BEFORE BREAKFAST
# TAB JANUMET 2.5/500 MG 1TAB TWICE DAILY BEFORE FOOD
# TAB LEVIPIL 750 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB PANTOP 40 MG 1 TAB BEFORE BREAKFAST
#
# VisitId: 2380452
# Matching Medicines : ==>
# TAB GABAPIN NT 100 MG ONCE AT NIGHT
# TAB SHELCAL 500 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB AMLONG 5 MG IF BP &GT140/90 MG SOS
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB GALVUS MET 50/500 1 TAB TWICE DAILY BEFORE FOOD
# TAB LEVIPIL 750 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB PRAMIPEX 0.25 MG 1/2 TAB AT NIGHT AFTER MEAL
# CAP DUVANTA 30 MG ONCE AT NIGHT
#
# VisitId: 2380464
# Matching Tests : ==>
# INR
# PT INR
#
# VisitId: 2380495
# Matching Medicines : ==>
# TAB PANGRAF 4 MG BD
# TAB TENVIR 25 MG OD
# TAB WYSOLONE 5 MG OD
# TAB THYRONORM 25 MCG OD
# TAB ESOSPRIN 75 MG OD
# TAB CEFTUM 500 MG TWICE DAILY X 5 DAYS
# CAP EVION 600 MG OD
# TAB ZORYL FORTE 1 BD
# TAB MYFORTIC 360 MG BD
# TAB ULTRACET 1 SOS FOR PAIN
# SYP LOOZ 20 ML AT BEDTIME
# TAB MAGNORATE 500 MG BD
# SYP AMBROLITE 10 ML THRICE DAILY AFTER FOOD X 5 DAYS
#
# VisitId: 2380495
# Matching Tests : ==>
# USG WHOLE ABDOMEN
# CBC
# LIPID PROFILE
# UGI ENDOSCOPY
# LFT
# INR
# RFT
#
# VisitId: 2380496
# Matching Tests : ==>
# ECHO
# CBC
# BLOOD SUGAR R
# ECG
# KFT
# B12
# LFT
# FIBROSCAN
# Matching Medicines : ==>
# TAB ROSEDAY EZ 20 MG 1 OD
# TAB SHALCAL XT 1 OD
#
# VisitId: 2380505
# Matching Tests : ==>
# CBC
# KFT
# USG WHOLE ABDOMEN
# LFT
# Matching Medicines : ==>
# TAB PCM 500 MG 1 TAB SOS FOR FEVER
# CBC KFT LFT TYPHI DOT WIDAL DENGUE SEROLOGY NS 1 ANTIGEN
# SYP INSTARAFT 2 TSF TDS
# TAB PANTOCID 40 MG 1 TAB TWICE DAILY
# TAB CEFURIC CV 625 MG 1 TAB TWICE DAILY
#
# VisitId: 2380528
# Matching Medicines : ==>
# SIMETHICONE WITH CHARCOAL (GASOFLAT TABLET) AS ADVISED.
#
# VisitId: 2380535
# Matching Medicines : ==>
# CAP  LUMIA  60 K WEEKLY X 12 WEEKS
# CAP   KEY  B 12  ONCE DAILY
#
# VisitId: 2380544
# Matching Medicines : ==>
# TAB OFLOX 200MG TWICE A DAY
# TAB RIFAGUT 550MG TWICE A DAY
# SYP LOOZ 30 ML AT BEDTIME
# TAB CARDIVAS 3.125MG TWICE A DAY
# CAP ZEVIT 1 CAP ONCE A DAY
# TAB PANTOCID 40MG ONCE A DAY
#
# VisitId: 2380567
# Matching Tests : ==>
# TSH
# HBA1C
# ECHO
# ESR
# CBC
# CALCIUM
# CPK
# ECG
# TROP I
# KFT
# LIPID PROFILE
# NT PRO BNP
# LFT
# B12
#
# VisitId: 2380620
# Matching Tests : ==>
# XRAY PNS
#
# VisitId: 2380621
# Matching Tests : ==>
# TSH
#
# VisitId: 2380622
# Matching Tests : ==>
# CBC
# XRAY CHEST PA
# XRAY PNS
#
# VisitId: 2380756
# Matching Tests : ==>
# PFT
# CBC
# ESR
# KFT
# CRP
#
# VisitId: 2380762
# Matching Tests : ==>
# KFT
# CALCIUM
#
# VisitId: 2380792
# Matching Tests : ==>
# PFT
# HRCT CHEST
#
# VisitId: 2380809
# Matching Tests : ==>
# DEXA SCAN WHOLE BODY
# TSH
# HBA1C
# RA FACTOR
# ESR
# CKMB
# CPK
# URINE R/M
# COMPLETE HGM
# TROP I
# RENAL ARTERY DOPPLER
# ECG
# LIPID PROFILE
# KFT
# FIBROSCAN
# LFT
# PERIPHERAL BLOOD FILM
# HOLTER
# Matching Medicines : ==>
# SYP LOOZ 2 TSP SOS AT NIGHT IF CPONSTIPATED
# TAB TRYPTOMER 10 MG ONCE DAILY NIGHT
# INJ EMEST IV THRICE DAILY
# INJ MONOCEF 2 GM IV TWICE DAILY
# TAB ERITEL AM 40/5 MG ONCE DAILY
# CAP. ABETANEURON D3 ONCE DAILY
# SYP INSTARAFT 10 ML 10 MIN AFTER MEALS
# INJ PANTOCID 8 MG/HOUR INFUSION TO CONTNIUE
#
# VisitId: 2380811
# Matching Tests : ==>
# ECHO
# PT INR
# CBC
# ECG
# KFT
# LFT
# HBSAG
# USG SCROTUM
# INR
#
# VisitId: 2380823
# Matching Tests : ==>
# ECHO
# CBC
# TROP I
# KFT
# LIPID PROFILE
# B12
# LFT
# THYROID PROFILE
#
# VisitId: 2380828
# Matching Tests : ==>
# TSH
# HBA1C
# ECHO
# URINE R/M
# ECG
# TYPHI DOT IGM
# KFT
# URINE R/M C/S
# PS MP
# BLOOD C/S
# ESR
# CPK
# COMPLETE HGM
# TROP I
# LFT
# PERIPHERAL BLOOD FILM
# DENGUE SEROLOGY IGG IGM
# LIPASE
# MALARIAL ANTIGEN
# SCRUB TYPHUS IGM
# Matching Medicines : ==>
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
# SYP DIGENE 2 TSP SOS FOR GASTRITIS
# DENGUE NS 1 ANTIGEN
# TAB ONDEM MD SOS PREMEALS FOR VOMITING
# CAP. VSL 3 ONCE DAILY 5 DAYS
# TAB TAXIM O 400 MG TWICE DAILY 5 DAYS
#
# VisitId: 2380833
# Matching Tests : ==>
# LIPID PROFILE
# HBA1C
#
# VisitId: 2380837
# Matching Tests : ==>
# PT INR
# CBC
# ECG
# KFT
# HBSAG
# INR
#
# VisitId: 2380849
# Matching Medicines : ==>
# TAB LEVIPIL 500 MG 1 BVD
#
# VisitId: 2380853
# Matching Tests : ==>
# CBC
# ESR
# LFT
# Matching Medicines : ==>
# TAB FOLVITE 5 MG 1 TABLET ONCE DAILY
# TAB TOFADOZ 10 MG 1 TABLET TWICE DAILY
# TAB MESACOL OD 1.2 G 1 TABLET THRICE DAILY AFTER FOOD X 3 WEEKS
#
# VisitId: 2380864
# Matching Tests : ==>
# FBS
# PPBS
#
# VisitId: 2380868
# Matching Tests : ==>
# CBC
# BLOOD SUGAR R
# KFT
# FIBROSCAN
# LFT
# Matching Medicines : ==>
# TAB PANTOCID DSR 1 BD
# INSTARAFT SYP 2 TSF TDS
# TAB QVM 10 I OD
#
# VisitId: 2380872
# Matching Medicines : ==>
# TAB DYTOR PLUS 10/50 HALF TABLET OD
# TAB NEXDOM 250 SOS
# TAB SEBELIUM 5 HS
# SYP SUCRALFATE SOS
# TAB APIBAN 2.5 BD
# TAB PAN DSR OD
# TAB BOSONEXT 2.5 OD
#
# VisitId: 2380873
# Matching Tests : ==>
# PT INR
# CBC
# ECG
# KFT
# HBSAG
# INR
#
# VisitId: 2380903
# Matching Tests : ==>
# KFT
#
# VisitId: 2380914
# Matching Tests : ==>
# DEXA SCAN WHOLE BODY
# USG WHOLE ABDOMEN
# ECHO
# FUNDUS AND REFRACTION
# ECG
# MRI BRAIN
# Matching Medicines : ==>
# TAB NAXDOM 250 MG TWICE DAILY 3 DAYS THEN SOS
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
# TAB TRYPTOMER 10 MG ONCE DAILY NIGHT
# CAP NERVZ B ONCE DAILY - 90 DAYS
# TAB ROSUVAS F 10+160 MG ONCE DAILY NIGHT
# CAP PANTOCID 40 MG ONCE DAILY EMPTY STOMACH 5 DAYS
# ZOLMIST NASAL SPRAY 2 PUFFS BOTH NOSTRIL SOS BASIS FOR HEADACHE AS EXPLAINED
# TAB CIPLAR LA 20 MG TWICE DAILY
#
# VisitId: 2380925
# Matching Tests : ==>
# CBC
# BLOOD SUGAR R
# KFT
# TYPHI DOT IGM
# B12
# LFT
# Matching Medicines : ==>
# TAB CALPOL 650 MG 1 SOS
# TAB QVM 10 I BD
# TAB MONDELESOR 1 OD
# TAB CEFURIC CV 625 MG 1 BD
# NEZAFLOW NASAL SPRAY OD
#
# VisitId: 2380928
# Matching Tests : ==>
# HBA1C
# CBC
# ECG
# LIPID PROFILE
# LFT
# RFT
#
# VisitId: 2380941
# Matching Tests : ==>
# LFT
#
# VisitId: 2380947
# Matching Medicines : ==>
# TAB ULTRACET SOS FOR PAIN
# TAB PREGALIN/ NT75/ 10  MG AT BED TIME
#
# VisitId: 2380950
# Matching Medicines : ==>
# TAB. IROSOME 1 TAB ONCE DAILY AT BEDTIME
# TAB. GUTFRIEND ORALLY TWICE DAILY.( AFTER FOOD)
# TAB. AMANTREL 100 MG 1 TAB TWICE DAILY AT 10 AM / 10 PM
# TAB. URIMAX - D 0.5 MG 1 TAB ONC DAILY AT BEDTIME
# TAB. ISOLAZINE 1TAB THRICE DAILY AT 10 AM /2 PM/ 10 PM
# SYP. CREMAFFIN PLUS 10 ML AT BEDTIME FOR CONSTIPATION.'
# TAB. COLOSPA ORALLY TWICE DAILY (AFTER LUNCH AND DINNER)
# TAB. DULANE - PG 20/75 MG 1 TAB ONCE DAILY AT BEDTIME
# TAB. PANTOCID 40 MG ORALLYONCE DAILY BEFORE BREAKFAST
# TAB. CARDIVAS 3.125MG ORALLY TWICE DAILY AT 7:00AM/ 7:00PM.
# TAB ARKAMINE 0.1 MG THRICE DAILY
# TAB. BRILINTA 90 MG ORALLY TWICE DAILY (10:00 AM / 10:00 PM)
# TAB. PLANEP 25 MG 1 TAB ONCE DAILY AT 7 AM
# TAB. ATORVA 80 MG ORALLYONCE DAILY AT BED TIME
# TAB. ECOSPRIN 75 MG ORALLYONCE DAILY AT BED TIME
# TAB. GABAPIN 100 MG 1/2 TAB AT BEDTIME
# TAB. TRIKA 0.5 MG 1 TAB ONCE DAILY AT BEDTIME
#
# VisitId: 2380956
# Matching Tests : ==>
# CBC
# KFT
# BLOOD SUGAR R
# LFT
# Matching Medicines : ==>
# TAB ROSEDAY 20 MG 1 OD
# TAB AMARYL 1 MG 1 OD
# TAB JALRA M 50/500 MG 1 BD
# TAB BENITOWA 4 MG 1 OD
#
# VisitId: 2380969
# Matching Tests : ==>
# FBS
# HBA1C
# PPBS
# LFT
# Matching Medicines : ==>
# TAB LIBRAX 1 TABLET TWICE DAILY X 30 DAYS
# TAB DROTIN M 1 SOS FOR PAIN
# TAB ZENTEL 400 MG STAT
# SYP LOOZ 20 ML AT BEDTIME X 3 MONTHS
#
# VisitId: 2380970
# Matching Tests : ==>
# TSH
# HBA1C
# ECHO
# USG ABDOMEN WITH PVR
# URINE R/M
# ECG
# PSA
# KFT
# URINE R/M C/S
# BLOOD C/S
# ESR
# CPK
# COMPLETE HGM
# TROP I
# LFT
# SR PSA FREE TOTAL
# CBC
# CKMB
# LIPASE
# Matching Medicines : ==>
# TAB EMBETA XR 50 ONCE DAILY
# INJ EMESET IV THRICE DAILY
# TAB OLMI AM 20/5 ONCE DAILY
# INJ HIR AS PER SLIDING SCALE PREMEALS S/C
# TAB ONDEROMET 2.5/500 MG TWICE DAILY
# INJ NS 50 ML PER HOUR
# TAB ROSUVAS 40 MG ONCE DAILY
# INJ LANTUS 10 UNIT 10 PM &GT 200 S/C
# INJ DROTIN IV TWICE DAILY
# CAP. REDOTIL SOS IF DIARRHEA PERSISITS MAXIMUM THRICE 1 CAP
# INJ MONOCEF 2 GM IV THRICE DAILY
# INJ METROGYL IV THRICE DAILY
# CAP. VSL 3 ONCE DAILY
#
# VisitId: 2380978
# Matching Tests : ==>
# KFT
# PFT
#
# VisitId: 2380993
# Matching Medicines : ==>
# TAB SOMPRAZ D 1 BD
# TAB BENADON 40 MG 1/2 OD
# TAB GABAPIN NT 100 MG 1 OD
# TAB RCINEX 600/300 MG 1 OD
# TAB MYCOBUTOL 1000 MG 1 OD
#
# VisitId: 2380999
# Matching Tests : ==>
# CBC
# CRP
# ESR
# LFT
#
# VisitId: 2380999
# Matching Tests : ==>
# DEXA SCAN WHOLE BODY
#
# VisitId: 2381005
# Matching Tests : ==>
# LIPID PROFILE
# B12
#
# VisitId: 2381010
# Matching Medicines : ==>
# TAB. DYTOR 10 MG ORALLY ONCE DAILY (10:00 AM)
# TAB. IVABRAD 5MG ORALLY TWICE DAILY (7:00 AM/ 7:00 PM)
# TAB. ISOLAZINE 1 TABLET ORALLY TWICE DAILY (7:00 AM / 7:00 PM)
# TAB. PANTOCID 40 MG ORALLY ONCE DAILY BEFORE BREAKFAST
# TAB. CLOPITAB 75MG ORALLY ONCE DAILY AT BED TIME
# TAB. STORVAS 80 MG ORALLY ONCE DAILY AT BEDTIME
# TAB. GIBTULIO 10 MG ORALLY ONCE DAILY WITH LUNCH
# TAB. ECOSPRIN 75 MG ORALLY ONCE DAILY AT BED TIME
# SYP. LOOZ 20ML AT BEDTIME SOS FOR CONSTIPATION
#
# VisitId: 2381010
# Matching Medicines : ==>
# K BIND SACHET DISSOLVED IN HALF GLASS OF WATER TWICE DAILY FOR 2 DAYS
#
# VisitId: 2381010
# Matching Medicines : ==>
# TAB ONDERO 5 MG ONCE DAILY BEFORE BREAKFAST
#
# VisitId: 2381012
# Matching Tests : ==>
# CBC
# KFT
# INR
# LFT
# Matching Medicines : ==>
# POWDER BCA HEP 2 SCOOPD TDS
# CAP. ZEVIT 1 CAP OD
# TAB. TELMA 40 MG OD- MORNING
# TAB. CARDIVAS 3.125 MG OD
# TAB. RIFAGUT 550 MG BD
# SYP LOOZ 30 ML AT BEDTIME
# TAB. STAMLO 5 MG OD- EVENING
# TAB. PANTOCID 40 MG OD
# TAB. URSOCOL 300 MG BD
#
# VisitId: 2381019
# Matching Tests : ==>
# USG WHOLE ABDOMEN
# PT INR
# CBC
# ECG
# KFT
# LFT
# HBSAG
# INR
#
# VisitId: 2381026
# Matching Tests : ==>
# HBA1C
#
# VisitId: 2381033
# Matching Tests : ==>
# HBA1C
#
# VisitId: 2381042
# Matching Tests : ==>
# DEXA SCAN WHOLE BODY
# ESR
# COMPLETE HGM
# LFT
# PERIPHERAL BLOOD FILM
# Matching Medicines : ==>
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
# TAB UDILIV 150 MG TWICE DAILY 10 DAYS
# SYP INSTARAFT 10 ML 10 MIN AFTER MEALS 5 DAYS
# TAB ROSUVAS F 10+160 MG ONCE DAILY NIGHT
# SYP LOOZ 2 TSP SOS ONCE DAILY NIGHT IF CONSTIPATED
# CAP VELOZ 40 MG ONCE DAILY EMPTY STOMACH - 10 DAYS
# CAP ABETANEURON D3 ONCE DAILY 10 DAYS`
#
# VisitId: 2381045
# Matching Medicines : ==>
# TAB RIFAGUT 550 MG TWICE DAILY
# SYP LOOZ 30 ML TWICE DAILY
# TAB LEVIPIL 500 MG TWICE DAILY AFTER FOOD
# CAP BECOZINC 1 CAPSULE ONCE DAILY
# TAB ONDERO 5 MG AFTER BREAKFAST
# POWDER PROHANCE HP 2 SCOOPS THRICE DAILY WITH MILK/ WATER X 1 MONTHS
# CAP SOMPRAZ IT 1 CAPSULE ONCE DAILY BEFORE BREAKFAST
# HEPAMERZ SACHET 5 G 2 SACHETS TWICE DAILY WITH WATER
#
# VisitId: 2381045
# Matching Tests : ==>
# CBC
# INR
# LFT
# RFT
#
# VisitId: 2381046
# Matching Tests : ==>
# HBA1C
# CBC
# KFT
# LIPID PROFILE
# LFT
# THYROID PROFILE
# Matching Medicines : ==>
# TAB ZOLFRESH 10 MG 1 OD
# TAB PANTOCID DSR 1 TAB ONCE DAILY IN MORNING
# TAB BENITOWA TM 4/40 MG 1 TAB ONCE DAILY IN MORNING
# TAB ROSEDAY 10 MG 1 TAB AT BED TIME
# TAB TENIVA M 20/500 MG 1 TAB ONCE DAILY BEFORE LUNCH
# TAB JALRA M 50/500 MG 1 TAB TWICE DAILY BEFORE MEALS
#
# VisitId: 2381053
# Matching Tests : ==>
# BLOOD C/S
# SR PSA FREE TOTAL
# ESR
# PSA
# URINE R/M
# ECG
# KFT
# URINE R/M C/S
# LFT
# Matching Medicines : ==>
# SALT CAPSULES ONCE DAILY 5 DAYS THEN STOP
# TAB LEVOFLOX 500 MG ONCE DAILY 5 DAYS
# TAB ECOSPRIN AV 75/10 MG 1 TAB ONCE DAILY AT BEDTIME
# SYP LOOZ 2 TSP SOS AT NIGHT CONSTIPATED
# TAB ERITEL AM 40 / 5 MG 1 TAB OCNE DAILY IN MORNING
# TAB. ARICEP 5MG 1 TAB AT NIGHT.
# TAB FARONEM CV TWICE DAILY 5 DAYS
# TAB. ADMENTA 10MG 1 TAB AT NIGHT
# TAB. CALPOL 650 MG 1 TAB SOS (FOR FEVER AND HEADACHE)
# CAP VSL 3 ONCE DAILY 5 DAYS
#
# VisitId: 2381057
# Matching Medicines : ==>
# TAB EMBETA XR 50 OD
# TAB AZMARDA  50 BD
# TAB NOVASTAT GOLD 75/75/ 20 HS
# TAB ZORYL M 1 0D AFTER DINNER
# TAB ISTAMET DXR 10/100/1000 OD MORNING AFTER MEALS
# TAB TIMZID MR 35 BD
#
# VisitId: 2381069
# Matching Medicines : ==>
# CAP DUZELA 30 MG 1 CAP AFTER DNNER
# TAB ZENOXA OD 300 MG 1 TAB AFTER DINNER( STOP IF ANY SKIN ALLERGY DEVELOP)
# TAB GABAPIN NT 400 MG 1 TAB AFTER DINNER
#
# VisitId: 2381086
# Matching Medicines : ==>
# CAP D RISE 1 CAP ONCE IN A WEEK FOR 6 WEEKS
# TAB CCM 1 TAB OD FOR 3 MONTH
#
# VisitId: 2381087
# Matching Tests : ==>
# HBA1C
# CALCIUM
# URINE R/M
# RA FACTOR
# KFT
# FBS
# SUGAR CHARTING WITH GLUCOMETER
# PPBS
# THYROID PROFILE
# ESR
# CPK
# COMPLETE HGM
# TROP I
# FIBROSCAN
# LFT
# BMI
# ANTI TPO
# CKMB
# SUDOSCAN
# ANA - IF
# USG NECK
# Matching Medicines : ==>
# TAB VOLIBO 0.3 MG THRICE DAILY BEFORE MEALS
# TAB GLUCONORM SR 1000 MG TWICE DAILY AFTER MEALS
# CAP UDAPA S ONCE DAILY LUNCH TIME
# VOLINI GEL L/A
# TAB ZERODOL MR TWICE DAILY 5 DAYS
# CAP ABETANEURON D3 ONCE DAILY 15 DAYS
# TAB AMARYL 1 MG TWICE DAILY BEFORE BREAKFAST AND DINNER
#
# VisitId: 2381105
# Matching Tests : ==>
# BLOOD C/S
# ESR
# CBC
# LFT
# CRP
#
# VisitId: 2381126
# Matching Tests : ==>
# HBA1C
# UGIE/RUT
# CBC
# FIBROSCAN-LIVER
# LIPASE
# PERIPHERAL SMEAR FOR BLOOD PICTURE
# KFT
# LIPID PROFILE
# VITAMIN D
# B12
# LFT
# FIBROSCAN
# CRP
# THYROID PROFILE
#
# VisitId: 2381129
# Matching Medicines : ==>
# TAB. ZUSSANIL 40 MG 1 TAB TWICE DAILY (BEFORE MEALS)
# TAB. KEPPRA 500 MG 1 TAB TWICE DAILY TO CONTINUE
#
# VisitId: 2381132
# Matching Tests : ==>
# UROFLOWMETRY
#
# VisitId: 2381134
# Matching Medicines : ==>
# TAB JARDIANCE 10 MG TWICE DAILY
# TAB DILZEM CD 1 TAB ONCE DAILY
# ...
# CAP VELOZ 20 MG 1 OD BBF
# TAB DYTOR 10 MG 1 OD 10.00AM
#
# VisitId: 2401038
# Matching Medicines : ==>
# TAB DAPA 10MG OD
# TAB THYRONORM 12.5 MCG OD
# TAB BISONEXT 2.5 MG OD
# CAP SUNRISE 60K PER MONTH
# TAB RANTAC 150 MG BD
# TAB CLOPITAB- CV GOLD 75/75/20 MG HS
#
# VisitId: 2401042
# Matching Tests : ==>
# TSH
# HBA1C
# ECHO
# USG WHOLE ABDOMEN
# CALCIUM
# URINE R/M
# ECG
# LIPID PROFILE
# APTT
# B12
# RA FACTOR
# PT INR
# KFT
# ANTI HCV
# ESR
# FUNDUS AND REFRACTION
# CPK
# COMPLETE HGM
# TROP I
# LFT
# PERIPHERAL BLOOD FILM
# CKMB
# PT INR APTT
# ANA - IF
# HBSAG
# INR
# Matching Medicines : ==>
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
# CAP ABETANEURON D3 ONCE DAILY - 15 DAYS
# CAP D RISE 60 K ONCE WEEKLY 4 WEEKS
#
# VisitId: 2401046
# Matching Tests : ==>
# CBC
# KFT
# FBS
# LFT
# PPBS
#
# VisitId: 2401049
# Matching Tests : ==>
# HBA1C
# CBC
# ECG
# KFT
# LIPID PROFILE
# LFT
#
# VisitId: 2401057
# Matching Tests : ==>
# ECHO
#
# VisitId: 2401087
# Matching Tests : ==>
# CBC
# KFT
# B12
# LFT
# FIBROSCAN
# Matching Medicines : ==>
# TAB CALPOL 650 MG 1 SOS
# TAB CEFMEND 500 MG 1 BD
#
# VisitId: 2401106
# Matching Medicines : ==>
# TAB PANTOP 40 MG ONE TAB BEFORE BREAKFAST
# TAB DEPRAN 10 MG 1 TAB AFTER DINNER
# TAB STROCIT PLUS 500/800 ONE TAB TWICE DAILY AFTER MEALS
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB ARICEP 5 MG 1 TAB AFTER BREAKFAST
# TAB ADMENTA 10 MG 1 TAB AFTER BREAKFAST
# TAB CILACAR 10 MG ONCE DAILY
# TAB TELMA 40MG ONCE DAILY
# TAB ABAXIS 5 MG 1 TAB TWICE DAILY (TO STOP IN CASE OF ANY BLEEDING MANIFESTATION AND REPORT TO HOSPITAL)
# TAB OLIANZ 2.5MG AT BED TIME
# TAB ECOPRIN AV 75/20 MG OD
# TAB LEVIPIL 750MG ONE TAB TWICE DAILY AFTER MEALS
#
# VisitId: 2401116
# Matching Medicines : ==>
# TAB DEXORANGE 1 OD
# TAB SPINFREE 1 BD
# TAB OXYPENE 1 BD
# TAB JARDIANCE MET 12.5/500 MG 1 BD BEFORE LUNCH AND DINNER
# TAB ONDERO 5 MG 1 OD BEFORE LUNCH
#
# VisitId: 2401118
# Matching Tests : ==>
# CBC
#
# VisitId: 2401124
# Matching Tests : ==>
# HBA1C
# CBC
# CPK
# TROP I
# KFT
# LIPID PROFILE
# LFT
# THYROID PROFILE
# Matching Medicines : ==>
# TAB ROSEDAY 40 MG 1 TAB AT BED TIME
# TAB RAPILIF D 1 TAB AT BED TIME
# TAB DEPLATT A 75/75 MG 1 TAB AT BED TIME
# TAB CONCOR 2.5 MG 1 TAB ONCE DAILY IN AFTERNOON
# TAB ISOLAZINE 1 TAB TWICE DAILY
# TAB DYTOR PLUS 1 TAB ONCE DAILY IN MORNING
#
# VisitId: 2401127
# Matching Tests : ==>
# ECHO
# CBC
# BLOOD SUGAR R
# ECG
# KFT
# B12
# LFT
#
# VisitId: 2401134
# Matching Medicines : ==>
# TAB. THYRONORM 88 MG 1 TAB ONCE DAILY BEFORE BREAKFAST
# TAB BRILLINTA 90MG TWICE A DAY 9AM AND 10PM AFTER FOOD
# TAB. GABAPIN NT 100 MG 1 TAB TWICE DAILY AT BEDTIME
# TAB. ECOSPRIN 75 MG 1 TAB ONCE DAILY AT BEDTIME 10PM
# TAB AZMARDA 50 MG 1 BID 7.00AM-7.00PM
# TAB. ATORVAS 40 MG ORALLY ONCE DAILY AT BED TIME 10PM
# TAB. METOLAR XR 50 MG 1 TAB TWICE DAILY 8AM AND 8PM
# TAB. LCZ I HS- 7 DAYS.
# TAB. PLANEP 25 MG 1 OD 10.00AM
#
# VisitId: 2401134
# Matching Medicines : ==>
# CAP NEUGABA M 75 ORALLY ONCE DAILY AFTER BREAKFAST
#
# VisitId: 2401143
# Matching Tests : ==>
# PT INR
# CBC
# ECG
# KFT
# LFT
# HBSAG
# INR
#
# VisitId: 2401148
# Matching Medicines : ==>
# TAB CARDIVAS 3.125MG 1 TAB TWICE DAILY AFTER FOOD
# SYP GLYCEROL 30 ML  THRICE DAILY
# TAB MINIPRESS XL 2.5 MG 1 TAB AFTER DINNER
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB GERIPOD 8MG 1 TAB AFTER DINNER
# TAB SEVELAMER 800MG 1 TAB THRICE DAILY
# TAB ALFOO 10 MG 1 TAB AFTER DINNER
# TAB ADMENTA 10 MG 1 TAB AFTER BREAKFAST
# TAB AMLONG 5 MG TWICE DAILY AFTER FOOD
# SYP LACTIHEP 20 ML AT BED TIME
# TAB OROFER XT 1 TAB AFTER BREAKFAST
# TAB GALAMER 4 MG 1 TAB AFTER BREAKFAST
# TAB PANTOCID 40 MG 1 TAB BEFORE BREAKFAST
# TAB SOLICEPT 5 MG 1 TAB TWICE DAILY AFTER FOOD
#
# VisitId: 2401150
# Matching Tests : ==>
# CBC
# KFT
# LIPID PROFILE
# HBA1C
# Matching Medicines : ==>
# TAB FOLVITE 5/750 MG OD
# TAB AMTAS 5MG OD
# TAB FERISOME 30MG OD
# TAB ECOSPRIN- AV 75/40MG HS
# TAB PAN 40 MG BBF OD
#
# VisitId: 2401155
# Matching Medicines : ==>
# REFRESH TEAR EYE DROP SIX TIMES A DAY
# TAB.VELOZ 20MG 1 TAB ONCE DAILY INMORNING
# CAP REJUNEX OD 1 CAP ONCE DAILY
# TAB. ILOCIT 500MG 1 TAB TWICE DAILY
# TAB.EPILIVE 750 MG 1 TAB TWICEDAILY
# SYP. LOOZ 30 ML ONCE DAILY AT NIGHT THROUGH RT
#
# VisitId: 2401157
# Matching Medicines : ==>
# CAP AMANTREL 100 MG 1 CAP TWIEC DAILY AFTER FOOD
# TAB PENTANERVE NT 100 MG 1 TAB AFTER DINNER
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# CAP DUZELA 30 MG  1 CAP AFTER DINNER
# TAB SILODOL 8 MG 1 TAB AFTER DINNER
# TAB PETRIL MD 0.25 MG SOS FOR ANXIETY
# TAB MIRABRON 25 MG 1 TAB AFTER DINNER
# TAB SHELCAL 5000 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB TRYPTOMER 10 MG 1 TAB AFTER DINNER
# CAP PANTOCID DSR 1 CAP BEFORE BREAKFAST
# TAB SYNDOPA 110 MG 1 TAB TWICE DAILY 1 HOUR BEFORE FOOD
# TAB NAXDOM 500 MG SOS FOR HEAD PAIN
# TAB STALOPAM 5 MG 1 TAB AFTER DINNER
# TAB PRAMIPEX 0.25 MG 1/2 TAB AFTER DINNER
# TAB INDERAL LA 20 MG 1 TAB AFTER DINNER
#
# VisitId: 2401165
# Matching Medicines : ==>
# TAB ATORVA 40 HS
# TAB GLUCONORM SR 500 BD
# TAB CLOPITAB A 75/75 BD
#
# VisitId: 2401175
# Matching Medicines : ==>
# TAB ECOSPRIN AV 150/40 MG BD
#
# VisitId: 2401180
# Matching Tests : ==>
# TSH
# HBA1C
# CBC
# ECG
# HBSAG
# INR
#
# VisitId: 2401211
# Matching Medicines : ==>
# TAB CILODOC 50 MG BD.
#
# VisitId: 2401217
# Matching Tests : ==>
# HBSAG
#
# VisitId: 2401223
# Matching Tests : ==>
# UROFLOWMETRY
#
# VisitId: 2401224
# Matching Medicines : ==>
# INJ LANTUS 16 UNITS HS
# SYP INSTARAFT 2 TSF TDS FOR PAIN ABDOMEN
# TAB GASTER D 1 TDS
# FORACORT INHALER 2 PUFF 12 HRLY
# TAB JARDIANCE 25 MG 1 OD
# BEESVIL 200 MG ROTACAP 1 OD
#
# VisitId: 2401244
# Matching Tests : ==>
# URINE ANALYSIS
# UROFLOWMETRY
#
# VisitId: 2401254
# Matching Tests : ==>
# LIPID PROFILE
# FBS
# HBA1C
# PPBS
#
# VisitId: 2401267
# Matching Medicines : ==>
# CAP AMANTREL 100 MG 1 CAP TWICE DAILY AFTER FOOD
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB STALOPAM 10 MG 1 TAB AFTER DINNER
# TAB SYNDOPA PLUS 125 MG 1 TAB THRICE DAILY 1 HOUR BEFORE FOOD
# TAB PRAMIPEX 0.5 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB GABAPIN NT 200 MG 1 TAB AFTER DINNER
# TAB CALBOZIN  1 TAB TWICE DAILY AFTER FOOD
# TAB NAXDOM 500 MG SOS FOR HEAD PAIN
# TAB TRYPTOMER 25 MG 1 TAB AFTER DINNER
# TAB SAFION 50 MG 1 TAB AFTER BREAKFAST
# TAB TOPAZ 25 MG 1 TAB TWICE DAILY AFTER FOOD
#
# VisitId: 2401301
# Matching Tests : ==>
# CBC
# HBA1C
# LFT
#
# VisitId: 2401312
# Matching Tests : ==>
# TSH
# HBA1C
# ECHO
# USG WHOLE ABDOMEN
# CALCIUM
# URINE R/M
# ECG
# LIPID PROFILE
# APTT
# B12
# RA FACTOR
# PT INR
# PSA
# KFT
# FBS
# SUGAR CHARTING WITH GLUCOMETER
# PPBS
# ANTI HCV
# ESR
# FUNDUS AND REFRACTION
# CPK
# COMPLETE HGM
# TROP I
# LFT
# PERIPHERAL BLOOD FILM
# SR PSA FREE TOTAL
# CKMB
# PT INR APTT
# ANA - IF
# HBSAG
# INR
# Matching Medicines : ==>
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
# CAP NERVZ B ONCE DAILY - 15 DAYS
# CAP D RISE 60 K ONCE WEEKLY 4 WEEKS
#
# VisitId: 2401317
# Matching Medicines : ==>
# TAB ALRISITA SR 150 MG 1 TAB AFTER BREAKFAST
# TAB GABAPIN NT 100 MG 1 TAB AFTER DINNER
# CAP AMANTREL 100 MG 1 CAP TWICE DAILY AFTER FOOD
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB GARDENAL 30 MG MORNING & 60 MG NIGHT
# TAB PALMIFLAME 1 TAB TWICE DAILY AFTER FOOD
# TAB ZENOXA OD 150 MG 1 TAB AFTER DINNER FOR 3 DAYS
# TAB ET DONE 25 MG 1/2 TAB AFTER DINNER
# TAB PRAMIPEX 0.25 MG 1/2 TAB AFTER DINNER
# CAP DUZELA 30 MG 1 CAP AFTER DINNER
# TAB STORVAS 20 MG 1 TAB AFTER DINNER
# TAB SYNDOPA 110 MG 1/2 TAB TWICE DAILY 1 HOUR BEFORE FOOD
#
# VisitId: 2401324
# Matching Tests : ==>
# TSH
# HBA1C
# ECHO
# USG WHOLE ABDOMEN
# CALCIUM
# URINE R/M
# ECG
# LIPID PROFILE
# APTT
# B12
# RA FACTOR
# PT INR
# KFT
# ANTI HCV
# ESR
# CPK
# COMPLETE HGM
# TROP I
# LFT
# PERIPHERAL BLOOD FILM
# CKMB
# PT INR APTT
# ANA - IF
# HBSAG
# INR
# Matching Medicines : ==>
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
# TAB OROFER XT ONCE DAILY 15 DAYS
# CAP D RISE 60 K ONCE WEEKLY 4 WEEKS
# CAP NERVZ B ONCE DAILY - 15 DAYS
# SYP LOOZ 1 TSP ONCE DAILY NIGHT IF CPONSTIPATED
#
# VisitId: 2401330
# Matching Tests : ==>
# CBC
# KFT
# B12
# LFT
# FIBROSCAN
# Matching Medicines : ==>
# TAB EZACT MR 90 MG 1 OD
#
# VisitId: 2401339
# Matching Medicines : ==>
# TAB SHELCAL 500 MG 1  TAB ONCE DAILY FOR 3 MONTHS
#
# VisitId: 2401345
# Matching Tests : ==>
# TSH
# HBA1C
# ECHO
# URINE R/M
# ECG
# TYPHI DOT IGM
# KFT
# URINE R/M C/S
# PS MP
# BLOOD C/S
# ESR
# CPK
# COMPLETE HGM
# TROP I
# GENEXPERT
# LFT
# PERIPHERAL BLOOD FILM
# DENGUE SEROLOGY IGG IGM
# MALARIAL ANTIGEN
# SCRUB TYPHUS IGM
# Matching Medicines : ==>
# TAB CALPOL 650 MG SOS FOR FEVER HEADACHE BODYACHES
# SYP PIRITON CS 1 TSP SOS FOR COUGH MAX TWICE DAILY 3 DAYS THEN SOS
# TAB AZEE 500 MG ONCE DAILY 5 DAYS
# DENGUE NS 1 ANTIGEN
# CONTINUE TAB GARDINAL 30 MG ONCE DAILY MORNING AS BEFORE
# GARDINAL 30 ONCE HTN 1/2 TAB AMLIP 5 C/O COUGH AND HAEMOPTYISIS
# CONTINUE TAB AMLIP 5 MG ONCE DAILY AS BEFORE
# CAP VELOZ 40 MG ONCE DAILY EMPTY STOMACH - 5 DAYS
# CAP ABETANEURON D3 ONCE DAILY 15 DAYS
# CAP. VSL 3 ONCE DAILY 5 DAYS
# CONTINUE TAB LEVIPIL 500 MG TWICE DAILY AS BEFORE
# TAB TAXIM O 400 MG TWICE DAILY 5 DAYS
# SYP APTIVATE 1 TSP TWICE DAILY 5 DAYS
# TAB MONTAIR FX ONCE DAILY NIGHT 5 DAYS
#
# VisitId: 2401351
# Matching Medicines : ==>
# TAB ELIQUIS 5 MG 1 BID
# TAB DILZEM CD 90 MG 1 BID
# TAB DYTOR PLUS  LS 10/25 MG 1 OD
#
# VisitId: 2401357
# Matching Tests : ==>
# TSH
# CBC
# ECG
# KFT
# APTT
# LFT
# HBSAG
# INR
#
# VisitId: 2401365
# Matching Tests : ==>
# TSH
# HBA1C
# RA FACTOR
# ESR
# URINE R/M
# ECG
# KFT
# B12
# LFT
# PERIPHERAL BLOOD FILM
# Matching Medicines : ==>
# CAP NERVZ B ONCE DAILY 30 DAYS
# TAB MONTAIR 10 MG ONCE DAILY NIGHT FOR 5 DAYS
# SYRUP PIRITON CS 2 TSF SOS FOR COUGH MAX TWICE DAILY 2 DAYS THEN SOS
# TAB OROFER XT ONCE DAILY 1 MONTH
# SEROFLO INHALER 250 UGM 2 PUFFS TWICE DAILY MDI 10 DAYS ( ORAL RINSE WITH WATER AFTER USE )
# TAB. CALPOL 650 MG 1 TAB SOS (FOR FEVER AND HEADACHE)
#
# VisitId: 2401366
# Matching Tests : ==>
# CBC
# RFT
# Matching Medicines : ==>
# TAB PAN 40 MG BBF
# TAB THYRONORM 50 MG BBF
# TAB ROSUVA 20 MG HS
# TAB AZEE 500 MG OD FOR 5 DAYS
# TAB CEFTUM 500MG BD FOR 5 DAYS
# TAB CILACAR-T 10/40 MG BD
# TAB METOLAR XR 50 MG OD
# SYP ASCORIL 2TSF BD
# TAB BRILINTA 90 MG BD
# TAB ECOSPRIN 75 MG OD
#
# VisitId: 2401369
# Matching Medicines : ==>
# TAB ECOSPRIN 75 MG 1 TAB AFTER DINNER
# TAB ATORVAS 20 MG 1 TAB AFTER DINNER
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB EMSET 4 MG 1 TAB SOS FOR VOMITING
# TAB BRIVGARD 50 MG 1 TAB TWICE DAILY AFTER FOOD
# CAP PANTOCID DSR 1 CAP BEFORE BREAKFAST
# TAB MOXOVAS 0.3 MG ONCE DAILY
# TAB STALOPAM 5 MG 1 TAB AFTER DINNER
# TAB AMLOPRESS 5 MG ONCE DAILY AFTER FOOD
#
# VisitId: 2401375
# Matching Tests : ==>
# CBC
# KFT
# LIPID PROFILE
# B12
# LFT
# THYROID PROFILE
#
# VisitId: 2401384
# Matching Tests : ==>
# UROFLOWMETRY
#
# VisitId: 2401386
# Matching Tests : ==>
# CBC
# KFT
# LFT
# HBSAG
#
# VisitId: 2401392
# Matching Tests : ==>
# CBC
# KFT
# LIPID PROFILE
# B12
# LFT
# THYROID PROFILE
#
# VisitId: 2401402
# Matching Tests : ==>
# TSH
# HBA1C
# CBC
# ECG
# KFT
# FBS
# APTT
# LFT
# HBSAG
# INR
# TVS
#
# VisitId: 2401415
# Matching Medicines : ==>
# CONTINUE TAB AXIDEX 1 MG ONCE DAILY
# TAB BIGCAL ONCE A DAY
#
# VisitId: 2401429
# Matching Medicines : ==>
# TAB SHELCAL 500 MG 1 TAB TWICE DAILY AFTER FOOD
# CALCIROL SACHET ONCE A WEEK
# TAB OLEANZ 2.5 MG 1 TAB AFTER DINNER
# TAB DUVITO 1 TAB TWICE DAILY AFTER FOOD
# TAB PETRIL MD 0.25 MG SOS FOR ANXIETY
# TAB PENTANERVE NT 400 MG 1 TAB AFTER DINNER
# TAB TRYPTOMER 10 MG 1 TAB AFTER DINNER
# TAB NAXDOM 500 MG SOS FOR HEAD PAIN
# TAB DEPRAN 10 MG 1/2 TAB AFTER DINNER
# TAB PANTOCID 40 MG 1 TAB BEFORE BREAKFAST
#
# VisitId: 2401435
# Matching Medicines : ==>
# TAB DYTOR PLUS LS 10/25 MG ONCE DAILY 8 AM
# TAB BILYPSA 4 MG AT BEDTIME
# CAP EVION 400 MG TWICE DAILY AFTER FOOD
# TAB HYPODRIN 2.5 MG THRICE DAILY
# PROHANCE HP POWDER 2 SCOOPS TWICE DAILY WITH WARM WATER
# CAP PANTOCID DSR ONCE DAILY BEFORE BREAKFAST
#
# VisitId: 2401439
# Matching Medicines : ==>
# TAB DEPRAN 10 MG 1 TAB AFTER DINNER
# TAB ADMENTA 10 MG 1 TAB AFTER BREAKFAST
# TAB DEPLATT 75 MG 1 TAB AFTER DINNER
# TAB ATORVA 10 MG 1 TAB AFTER DINNER
# CAP PANTOCID DSR 1 CAP BEFORE BREAKFAST
# TAB OLEANZ 2.5 MG 1/2 TAB AFTER DINNER
# TAB TEBOKEN FORTE 120 MG 1 TAB TWICE DAILY AFTER FOOD
# TAB ARICEP 10 MG 1 TAB AFTER BREAKFAST
# TAB PACITANE 2 MG 1/2 TAB TWICE DAILY AFTER FOOD
#
# VisitId: 2401444
# Matching Medicines : ==>
# TAB ECOSPRIN GOLD 75/75/20 OD
#
# VisitId: 2401447
# Matching Tests : ==>
# USG WHOLE ABDOMEN
# ECHO
# PT INR
# CBC
# PSA
# ECG
# KFT
# LFT
# HBSAG
# INR
#
# VisitId: 2401456
# Matching Tests : ==>
# USG WHOLE ABDOMEN
# PT INR
# CBC
# ECG
# KFT
# LFT
# HBSAG
# INR
#
# VisitId: 2401457
# Matching Medicines : ==>
# TAB SHELCAL 1 TAB ONCE DAILY FOR 3 MONTHS
# TAB GABAPENTIN 100 MG 1 TAB ONCE DAILY FOR 7 DAYS
# TAB ULTRACET 1 TAB SOS
#
# VisitId: 2401470
# Matching Tests : ==>
# CBC
# BLOOD SUGAR R
# KFT
# TYPHI DOT IGM
# LFT
# Matching Medicines : ==>
# TAB SOMPRAZ D 1 BD
# TAB MONTEC LC 1 OD
# TAB CALPOL 650 MG 1 SOS
# TAB QVM 10 I BD
# TAB CEFURIC CV 625 MG 1 BD
#
# VisitId: 2401486
# Matching Medicines : ==>
# INJ LUPRIDE DEPOT ( ELIGUARD ) 6 MNTHS DEPOT STAT DOSE
#
# VisitId: 2401496
# Matching Medicines : ==>
# TAB LINID 600 MG 1 TAB TWICE A DAY DAY
#
# VisitId: 2401496
# Matching Tests : ==>
# PT INR
# CBC
# ECG
# KFT
# LFT
# HBSAG
# INR
#
# VisitId: 2401499
# Matching Medicines : ==>
# TAB CONCOR 2.5 MG 1 OD
#
# VisitId: 2401500
# Matching Tests : ==>
# CBC
# AFP
# Matching Medicines : ==>
# TAB DYTOR PLUS 10/50 MG ONCE DAILY
# TAB RCIFAX 450 MG TWICE DAILY
# TAB URSOCOL SR 450 MG TWICE DAILY
# TAB HEPTRAL / NUSAM 400 MG TWICE DAILY
#
# VisitId: 2401517
# Matching Tests : ==>
# FBS
# PPBS
#
# VisitId: 2401527
# Matching Tests : ==>
# HBA1C
# CBC
# KFT
# LIPID PROFILE
# LFT
# Matching Medicines : ==>
# TAB GLUCONORM SR 500 BD
# TAB ROSUVAS 20 HS
# SYP NEOGADINE 1 TSF TDS
# TAB CLOPITAB A 75/75 BD
# TAB CYPROHEPTADINE 2MG HS
# TAB PANTOCID DSR 40 OD
#
# VisitId: 2401542
# Matching Medicines : ==>
# TAB GABAPIN 300 MG 1 TAB AT BED TIME
# TAB NUROKIND GOLD 1 TAB ONCE DAILY
# TAB BIG CALZ 1 TAB ONCE DAILY
# TAB RAPILIF M 1 TAB AT BED TIME
# TAB D RISE 60 K ONCE WEEKY
#
# VisitId: 2401548
# Matching Medicines : ==>
# TAB ECOSPRIN 75 MG 1 HS
# TAB QVM 10 I BD
# TAB SOMPRAZ D 1 OD
# TAB UBNOL 1 BD
# TAB PEXEP CR 12.5 MG 1 HS
#
# VisitId: 2401557
# Matching Tests : ==>
# HBA1C
# URINE R/M
# ECG
# APTT
# B12
# RA FACTOR
# PT INR
# KFT
# THYROID PROFILE
# ESR
# COMPLETE HGM
# LFT
# PERIPHERAL BLOOD FILM
# VITAMIN B12
# ANTI TPO
# CBC
# PT INR APTT
# ANA - IF
# INR
# USG NECK
# Matching Medicines : ==>
# TAB TRENEXA 500 MG ONE TAB STAT AST NIGHT IF BLEEDING THEN AFTER TWICE DAILY 2 DISE SOS IF BLEEDING PERSISTS ELSE STOP
# TAB SEDEROM OD 2 HOURS AFTER MEALS
# TAB. VELOZ 40 MG 1 TAB ONCE DAILY FOR 5 DAYS (EMPTY STOMACH DAILY MORNING)
# TAB XARELTO 15 MG TWICE DAILY WITH MEALS
# CAP. ABETANEURON D3 1 CAP ONCE DAILY.
# NASOCLEAR NASAL DROPS THRICE DAILY 2 DROPS
# TAB. CALPOL 650 MG 1 TAB SOS (FOR FEVER AND HEADACHE)
# TAB. FARONEM CV 1 TAB TWICE DAILY FOR 5 DAYS (AFTER MEALS)
# CAP VSL 3 ONCE DAILY 5 DAYS
#
# VisitId: 2401569
# Matching Medicines : ==>
# TAB ELIQUIS 5 MG 1 TAB TWICE DAILY (AFTER FOOD)
# TAB AZMARDA 50 MG 1/2 TAB TWICE DAILY (AFTER FOOD)
# CAP ECOSPRIN AV 75/40 MG 1 TAB ONCE DAILY (AFTER DINNER)
# TAB STARPRESS XL 25 MG 1 TAB ONCE DAILY (AFTER BREAKFAST )
# TAB IVABRAD 5 MG 1 TAB TWICE DAILY (AFTER FOOD)
#
# VisitId: 2401573
# Matching Medicines : ==>
# TAB ECOSPRIN -
# TAB CILODOC 50 MG BD
# TAB APIXATOR 2.5 MG BD
# TAB GABAPENE 100 MG HS.
# TAB ULTRACET 1 HS
# TAB TRENTAL 400 MG TDS.
#
# VisitId: 2401583
# Matching Tests : ==>
# CBC
#
# VisitId: 2401602
# Matching Tests : ==>
# FBS
# PPBS
#
# VisitId: 2401612
# Matching Medicines : ==>
# CAP REDROL DSR ONCE DAILY SOS
# TAB TENVIR AF 25 MG ONCE DAILY X 3 MONTHS
#
# VisitId: 2401612
# Matching Tests : ==>
# LFT
#
# VisitId: 2401620
# Matching Tests : ==>
# CBC
# KFT
# LFT
#
# VisitId: 2401635
# Matching Tests : ==>
# CBC
# KFT
# FBS
# LFT
# PPBS
#
# VisitId: 2401660
# Matching Medicines : ==>
# TAB SOMPRAZ D 1 BD
# TAB EZACT MR 90 MG 1 BD
# VOLITRA GEL
#
# VisitId: 2401662
# Matching Medicines : ==>
# TAB DAFLON 1 GM OD
#
# VisitId: 2401666
# Matching Medicines : ==>
# TAB. VELOZ 20 MG 1 TAB TWICE DAILY (BEFORE MEALS) X 7 DAYS
# NEVANAC EYE DROPS 1 DROP THREE TIMES BOTH EYES FOR 7 DAYS
# CAP. FELICITA OD 1 CAP. ONCE DAILY FOR 7 DAYS
# TAB. CALZIVIA 1 TAB. ONCE DAILY
# TAB. VOVERAN SR 1 TAB THRICE DAILY AFTER FOOD FOR 5 DAYS AND THEN SOS FOR PAIN
# SYP. LOOZ 20 ML AT BEDTIME FOR CONSTIPATION IF REQUIRED
# TAB. LAMREST 3 MG 1 TAB ONCE DAILY AT BEDTIME
# TAB EPILIVE 500 MG 1 TAB TWICE DAILY TO CONTINUE
# TAB. CEFTUM 500 MG 1 TAB TWICE DAILY FOR 3 DAYS (AFTER MEALS)
#
# VisitId: 2401690
# Matching Tests : ==>
# CBC
# KFT
#
# VisitId: 2401719
# Matching Tests : ==>
# ECHO
#
# VisitId: 2401752
# Matching Tests : ==>
# ECHO
#
# VisitId: 2401767
# Matching Tests : ==>
# CBC
# LIPID PROFILE
# HBA1C
# RFT
# Matching Medicines : ==>
# TAB TELMA-AM 40/5 BD
# TAB MINIPRESS- XL 2.5 MG BD
# TAB CARDIVAS 12.5 BD
# TAB NATRILIX-SR 1.5 MG OD
#
# VisitId: 2401781
# Matching Medicines : ==>
# TAB ECOSPRIN 75 M OD.
# TAB DOLO650 MG SOS.
# TAB RIVAXA  5MG BD

# %%
import pandas as pd
import re

# Read your CSV file and the Excel file
df_services = pd.read_csv('D:\\DataFrame\\Services.csv', header=0, encoding='ISO-8859-1')
df_medicine = pd.read_csv('D:\\DataFrame\\Medicine.csv', usecols=['ItemName'], encoding='ISO-8859-1')
df_plan_of_care = pd.read_excel("Downloads//EMR.xlsx")

# Filter the DataFrame to keep only rows where the 'Template' column is 'Plan of care'
df_filtered = df_plan_of_care[df_plan_of_care['Template'] == 'Plan of care']

# Split the ServiceName into two columns based on the first occurrence of '('
df_services[['ServiceName_Part1', 'ServiceName_Part2']] = df_services['ServiceName'].str.split('(', n=1, expand=True)

# Clean the second part of the ServiceName
df_services['ServiceName_Part2'] = df_services['ServiceName_Part2'].str.strip().str.rstrip(')').str.lstrip('(')
df_services = df_services[['ServiceName_Part1', 'ServiceName_Part2']]

# Create a new column with the first string from ItemName
df_medicine['FirstString'] = df_medicine['ItemName'].apply(lambda x: x.split()[0])

# Lists of tests and medicine keywords
tests = [
    "PT INR", "COMPLETE HGM", "ESR", "PERIPHERAL BLOOD FILM", "HBA1C", "APTT", "TSH", 
    "RA FACTOR", "ECG", "BLOOD C/S", "NT PROBNP", "PROCALCITONIN", "URINE R/M C/S", 
    "LFT", "KFT", "MRI BRAIN WITH MRA BRAIN NECK", "Calcium", "Urine R/M", "ECHO", 
    "CPK", "CKMB", "TROP I", "Chest X-ray PA", "B12", "USG Whole Abdomen", 
    "ANA - IF", "Lipid Profile", "Anti TPO", "USG Neck", "Thyroid Profile", "MRI Brain", 
    "Whole Spine Screening", "CT Chest", "ANA Immunoblot 17 Antigen", "DEXA Scan Whole Body", 
    "Sudoscan", "BMI", "Renal Artery Doppler", "Holter", "FBS", "PPBS", 
    "Sugar Charting with Glucometer", "Fundus and Refraction", "CBC", "RFT", "INR", 
    "AFP", "PSA", "Urine Routine and Culture", "USG Abdomen with PVR", "Uroflowmetry", 
    "Ultrasound Thyroid Gland", "HbsAg", "Anti HCV", "NT Pro BNP", "Peripheral Smear for Blood Picture", 
    "Dietician Opinion for Diabetic Diet", "UGIE/RUT", "Fibroscan-Liver", 
    "CECT Abdomen (Negative Oral Contrast)", "CECT Abdomen (IV and Oral Contrast)", "PS MP", 
    "Malarial Antigen", "Dengue NS1 Antigen", "Dengue Serology IgG IgM", "Scrub Typhus IgM", 
    "Typhi Dot IgM", "Chikungunya Serology IgG IgM", "Leptospira Serology IgG IgM", "Blood Sugar R", 
    "ABPM", "USG W/A", "SR PSA Free Total", "Chest X-Ray PA", "Sputum AFB Gram Stain C/S KOH", 
    "GeneXpert", "MRI Angio Brain and Neck", "Ultrasound Abdomen", "FibroScan", "PT INR APTT", 
    "Blood C/S"
]

medicine_keywords = [
    'CAPSULES', 'CREAM & OINTMENT', 'DROPS', 'GARGLE', 'INHALER',
    'INJECTION', 'LOTIONS', 'MISCELLANEOUS', 'PATCH', 'POWDER',
    'RESPULES', 'ROTACAP', 'SACHET', 'SPRAYS', 'SUPPOSITORY', 'SYRUP',
    'TABLET', 'VACCINE', 'CREAM', 'EYE OINTMENT', 'GEL',
    'SKIN OINTMENT', 'EAR DROP', 'EYE & EAR DROP', 'EYE DROP',
    'NASAL DROP', 'ORAL DROP', 'NASAL SPRAY', 'SKIN SPRAY', 'SPACER', 'TAB',
    'CustomMedication', 'SOLUTION', 'TOOTH PASTE', 'TAB.', 'tab', 'Tab.', 
    'Tab', 'SYP', 'syp', 'syp.', 'Syp', 'Syp.', 'INJ', 'INJ.', 'inj', 
    'Inj.', 'Inj', 'CAP', 'CAP.', 'cap.', 'cap', 'Cap', 'Cap.', 'NS', 'NS.'
]

# Initialize an empty list to store the output rows
output_rows = []

# Iterate over each row in the filtered DataFrame
for _, row in df_filtered.iterrows():
    visit_id = row['VisitId']
    data = row['Data']
    
    # Split the 'Data' column into sentences based on '<br/>' or ',' as delimiters
    sentences = [sentence.strip() for sentence in data.replace('<br/>', ',').split(',')]
    
    matching_tests = set()
    matching_medicine = set()
    
    for sentence in sentences:
        lower_sentence = sentence.lower()
        lower_service_part1 = df_services['ServiceName_Part1'].str.lower()
        lower_service_part2 = df_services['ServiceName_Part2'].str.lower()
        
        if lower_sentence in lower_service_part1.values or lower_sentence in lower_service_part2.values:
            matching_tests.add(sentence.upper())  # Convert to uppercase before adding

        # Find matches in the test list
        matches = [test.lower() for test in tests if re.search(rf'\b{re.escape(test)}\b', sentence, re.IGNORECASE)]
        for match in matches:
            matching_tests.add(match.upper())  # Convert to uppercase before adding
            
        # Find matches in the medicine keywords
        for medicine in medicine_keywords:
            if re.search(rf'\b{re.escape(medicine.lower())}\b', lower_sentence):
                matching_medicine.add(sentence.upper())  # Add the original sentence in uppercase
    
    # If there are matches, store them in the output rows list
    if matching_tests or matching_medicine:
        output_rows.append({
            'VisitId': visit_id,
            'Matching Medicines': ', '.join(matching_medicine),
            'Matching Tests': ', '.join(matching_tests)
        })

# Convert the output rows to a DataFrame
df_output = pd.DataFrame(output_rows)

# Save the output to a CSV file
df_output.to_csv('D:\\DataFrame\\matched_output.csv', index=False)

print("Output saved to 'D:\\DataFrame\\matched_output.csv'")
# Out:
# Output saved to 'D:\DataFrame\matched_output.csv'
